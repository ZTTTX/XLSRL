# %%
from dataclasses import dataclass
from typing import Any, List

from collections import namedtuple
from snake_egg import EGraph, Rewrite, Var, vars
import re
import networkx as nx
import matplotlib.pyplot as plt
from networkx.algorithms import isomorphism
import json
import subprocess
import time
from collections import deque
from itertools import count

import torch
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from math import ceil, log2

# %%
class Node:
    def __init__(self, name=None, bitwidth=None, operation=None, operands=None, 
                 idNum=None, value=-1, pos=None, FuncIO=None, start=None, width=None, array_sizes=None, indices=None):
        self.name = name
        self.bitwidth = bitwidth
        self.operation = operation
        self.operands = operands
        self.idNum = idNum
        self.value = value
        self.pos = pos
        self.FuncIO = FuncIO
        self.start = start
        self.width = width
        self.array_sizes = array_sizes
        self.indices = indices

    def __repr__(self):
        return f"Node(name={self.name}, bitwidth={self.bitwidth}, operation={self.operation}, operands={self.operands}, id={self.idNum}, value={self.value}, pos={self.pos}, FuncIO={self.FuncIO}, start={self.start}, width={self.width}, array_sizes={self.array_sizes}, indices={self.indices})"

def node_to_dict(node):
    return {
        "OperationName": node.name,
        "BitWidth": node.bitwidth,
        "OperationType": node.operation,
        "Operands": node.operands,
        "idNum": node.idNum,
        "Value": node.value,
        "Pos": node.pos,
        "FuncIO": node.FuncIO,
        "Start": node.start,
        "Width": node.width,
        "ArraySize": node.array_sizes,
        "Indices": node.indices
    }
    
def ParseIRFile(ir_text):
    nodes_dict = {}
    lines = ir_text.strip().split("\n")[:]
    return lines

def LineToDict(line):
#     print(line)
    nodes = []
    # Check for function header
    FuncIO = "Not"
    if "fn" in line:
        FuncIO = "In"
        signature_pattern = re.compile(r"fn\s+(\w+)\((.*?)\)\s*->\s*(.*?)\s*\{")
        signature_match = signature_pattern.search(line)
        if signature_match:
            func_name = signature_match.group(1)
            params = signature_match.group(2).split(',')
            for param in params:
                param_name, param_type = param.split(':')
                param_name = param_name.strip()
                array_sizes = [int(size) for size in re.findall(r'\[(\d+)\]', param_type)]
                if array_sizes == []:
                    array_sizes = None
                bitwidth = int(array_sizes.pop(0))  # The first size is the bitwidth
                node = Node(name=param_name, bitwidth=bitwidth, array_sizes=array_sizes, FuncIO="In")
                nodes.append(node)
        return nodes

    if "ret" in line:
        FuncIO = "Out"
        line = line[4:]
        
    if line == "}":
        return None

    # Extract node name
#     name = re.search(r"(\w+\.\d+):", line).group(1)
    name = re.search(r"(\w+(\.\d+)?)\:", line).group(1)

    # Extract bitwidth and array size
    array_pattern = re.compile(r"bits\[(\d+)\]((?:\[\d+\])*)")
    array_match = array_pattern.search(line)
    if array_match:
        bitwidth = int(array_match.group(1))
        array_sizes_str = array_match.group(2)
        array_sizes = [int(size) for size in re.findall(r'\[(\d+)\]', array_sizes_str)]
        if array_sizes == []:
            array_sizes = None
    
    # Extract operation
    operation = re.search(r"= (\w+)", line).group(1)

    # Extract operands; 
    # Eidt to ignore other argument keywords
    operands = re.findall(r"(\w+\.\d+|\w+)", line.split("=")[1])
    operands = [op for op in operands if op not in [operation, "value", "id", "pos", "start", "width", "indices"]]

    # Extract indices: only applies for array_indice node
    indices = None
    indices_match = re.search(r"indices=\[(.*?)\]", line)
    if indices_match:
        # Get the string of indices
        indices_str = indices_match.group(1)
        # Find all occurrences of literals or node names in the indices string
        indices = re.findall(r"(\w+\.\d+|\w+)", indices_str)
    
    # Extract id
    idNum = int(re.search(r"id=(\d+)", line).group(1))

    # Extract value (if present)
    value_match = re.search(r"value=(\d+)", line)
    value = int(value_match.group(1)) if value_match else -1

    # Extract pos (if present)
    pos_match = re.search(r"pos=\[\((\d+,\d+,\d+)\)\]", line)
    pos = tuple(map(int, pos_match.group(1).split(","))) if pos_match else None

    # Extract start and width for bit_slice (if present)
    start = None
    width = None
    if operation == "bit_slice":
        start = int(re.search(r"start=(\d+)", line).group(1))
        width = int(re.search(r"width=(\d+)", line).group(1))

    # Create Node object
    node = Node(name, bitwidth, operation, operands, idNum, value, pos, FuncIO, start, width, array_sizes, indices)
    
    # Add to node list
    nodes.append(node)
    return nodes

def DictToGraph(G, NodeDict):
    # This function turns the node dictionary to directional graph
    NodeList = []
    EdgeList = []
    for NodeName in NodeDict:
        if NodeDict[NodeName].FuncIO != "In": 
            # This if is for handling the function top input, they are treated as nodes as well.
            NodeList.append((NodeDict[NodeName].idNum, node_to_dict(NodeDict[NodeName])))
            for ParentName in NodeDict[NodeName].operands:
                if NodeDict[ParentName].FuncIO != "In":
                    EdgeList.append((NodeDict[ParentName].idNum, NodeDict[NodeName].idNum))
                else: 
                    EdgeList.append((NodeDict[ParentName].name, NodeDict[NodeName].idNum))
            if NodeDict[NodeName].indices != None:
                for ParentName in NodeDict[NodeName].indices:
                    if NodeDict[ParentName].FuncIO != "In":
                        EdgeList.append((NodeDict[ParentName].idNum, NodeDict[NodeName].idNum))
                    else: 
                        EdgeList.append((NodeDict[ParentName].name, NodeDict[NodeName].idNum))
        else:
            NodeList.append((NodeDict[NodeName].name, node_to_dict(NodeDict[NodeName])))
    G.add_nodes_from(NodeList)
    G.add_edges_from(EdgeList)
    return G
    
    
def slice_ir_by_function(ir_content):
    # Regular expression to match function definitions with and without "top"
    fn_pattern = re.compile(r"(?:top\s+)?fn\s+(\w+)\((.*?)\)\s*->\s*(.*?)\s*\{")

    # Split the content by lines for processing
    lines = ir_content.split('\n')

    # Dictionary to store each function's IR content
    functions_dict = {}

    # Buffer to store current function lines
    current_fn = None
    current_fn_lines = []

    # Iterate through each line
    for line in lines:
        # Check if the line starts a new function definition
        match = fn_pattern.match(line)
        if match:
            # If there is a current function being processed, save it
            if current_fn:
                functions_dict[current_fn] = '\n'.join(current_fn_lines)
                current_fn_lines = []
            # Start a new function
            current_fn = match.group(1)
        # Add the line to the current function's lines
        if current_fn:
            current_fn_lines.append(line)
        # Check if the line ends a function definition
        if line.strip() == '}':
            # Save the current function and reset
            if current_fn:
                functions_dict[current_fn] = '\n'.join(current_fn_lines)
                current_fn = None
                current_fn_lines = []

    # Return the dictionary with function names as keys and IR content as values
    return functions_dict

# %%
def count_registers_in_block(ir_content):
    # Flag to check if we are inside a 'block' section
    in_block_section = False
    register_count = 0

    # Splitting the content into lines
    lines = ir_content.splitlines()

    for line in lines:
        # Check if the 'block' section starts
        if line.strip().startswith("block "):
            in_block_section = True
        # Check if the 'block' section ends
        elif line.strip() == "}" and in_block_section:
            in_block_section = False
        # Count the registers if inside a 'block' section
        elif in_block_section and line.strip().startswith("reg "):
            register_count += 1

    return register_count

def ReadScheduleIR(file_path):
    TopFunctionName = None
    with open(file_path, 'r') as f:
        ir_content = f.read()
        ir_dict = slice_ir_by_function(ir_content)
    FuncNodeDict = {}
    for fn_name, fn_content in ir_dict.items():
        NodeDict = {}
        Lines = ParseIRFile(fn_content)
        for Line in Lines:    
            NodeList = LineToDict(Line)
            if NodeList != None:
                for NodeObj in NodeList:
                    NodeDict[NodeObj.name] = NodeObj
            if "top" in Line:
                TopFunctionName = fn_name
        FuncNodeDict[fn_name] = NodeDict
    SubCounter = 0
    NodeCounter = 0
    JsonOutDict = {}
    G_goble = nx.DiGraph()
    for fn_name, fn_nodes in FuncNodeDict.items():
        G = nx.DiGraph()
        G_goble = DictToGraph(G_goble, fn_nodes)
        
    register_count = count_registers_in_block(ir_content)
    return G_goble, register_count


def read_SDC_pipeline_result(file_path):
    max_stage_latency = 0
    with open(file_path, 'r') as file:
        file_contents = file.read()

    schedule_dict = {}
    current_stage = None
    current_node = None
    
    # Regular expressions to match the lines
    function_pattern = re.compile(r'^function: "(.*)"')
    stage_pattern = re.compile(r'^\s*stage: (\d+)')
    node_pattern = re.compile(r'^\s*node: "(.*)"')
    node_delay_pattern = re.compile(r'^\s*node_delay_ps: (\d+)')
    path_delay_pattern = re.compile(r'^\s*path_delay_ps: (\d+)')

    for line in file_contents.splitlines():
        # Check for function
        function_match = function_pattern.match(line)
        if function_match:
            schedule_dict['function'] = function_match.group(1)
            schedule_dict['stages'] = []
            continue
        
        # Check for stage
        stage_match = stage_pattern.match(line)
        if stage_match:
            current_stage = {'stage': int(stage_match.group(1)), 'timed_nodes': []}
            schedule_dict['stages'].append(current_stage)
            continue
        
        # Check for node
        node_match = node_pattern.match(line)
        if node_match:
            current_node = {'node': node_match.group(1)}
            current_stage['timed_nodes'].append(current_node)
            continue
        
        # Check for node delay
        node_delay_match = node_delay_pattern.match(line)
        if node_delay_match:
            current_node['node_delay_ps'] = int(node_delay_match.group(1))
            continue
        
        # Check for path delay
        path_delay_match = path_delay_pattern.match(line)
        if path_delay_match:
            cur_path_delay = int(path_delay_match.group(1))
            current_node['path_delay_ps'] = cur_path_delay
            if cur_path_delay > max_stage_latency:
                max_stage_latency = cur_path_delay
            continue
        
    return schedule_dict, max_stage_latency

def register_SDC_result(G, schedule_dict):
    stage_num = 0
    for cur_dict in schedule_dict['stages']:
        stage_num += 1
        cur_stage = cur_dict['stage']
        node_list = cur_dict['timed_nodes']
        for cur_node in node_list:
            # Check if the last part is an integer
            node_name_parts = cur_node['node'].split('.')
            if node_name_parts[-1].isdigit():
                # If it is, use it as the ID
                cur_node_id = int(node_name_parts[-1])
            else:
                # If not, use the entire node name as the ID
                cur_node_id = cur_node['node']
            
            G.nodes[cur_node_id]['node_delay_ps'] = cur_node['node_delay_ps']
            G.nodes[cur_node_id]['path_delay_ps'] = cur_node['path_delay_ps']
            G.nodes[cur_node_id]['stage'] = cur_stage
    return G, stage_num

# %%
def run_unify_name(ir_input_path, ir_unify_out):
    command = [
        "/home/miao/xls/bazel-bin/xls/tools/UnifyName",
        ir_input_path,
        ir_unify_out
    ]
    command_str = " ".join(command)
    try:
        result = subprocess.run(command_str, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
        result.check_returncode()  # This will raise an exception if the return code was non-zero
        print("Name Unification Run Done.")
    except subprocess.CalledProcessError as e:
        print("An error occurred while running the command.")
        print("Error message:", e.stderr)
    return

def run_rewriter(command_executable, ir_input_path, json_output_path, ir_output_path):
    print("\nRunning Standalone Rewriter")
    command = f"{command_executable} {ir_input_path} {json_output_path} {ir_output_path}"
    try:
        result = subprocess.run(command, shell=True, capture_output=True, text=True)
        result.check_returncode()
        print("Rewriter Run Done")
#         print("Output:", result.stdout)
    except subprocess.CalledProcessError as e:
        print("An error occurred while running the command.")
        print("Error message:", e.stderr)
    return

def run_sdc_scheduler(ir_output_path, output_verilog_path, schedule_result_path, output_schedule_ir_path, 
                      delay_model, TopFunctionName, clock_period_ps, clock_margin_precent, 
                      pipeline_stages, period_relaxation_percent):
    command = [
            "/home/miao/xls/bazel-bin/xls/tools/codegen_main",
            ir_output_path,
            '--generator=pipeline',  
            f'--delay_model={delay_model}',
            '--module_name=xls_test',  # Assuming module_name is static
            f'--top={TopFunctionName}',
            f'--output_verilog_path={output_verilog_path}',  
            f'--output_schedule_path={schedule_result_path}',
            f'--output_schedule_ir_path={output_schedule_ir_path}'  
        ]
        
    if clock_period_ps != None:
        command.append(f'--clock_period_ps={clock_period_ps}')
        if clock_margin_precent != None:
            command.append(f'--clock_margin_percent={clock_margin_precent}')
    elif pipeline_stages != None:
        command.append(f'--pipeline_stages={pipeline_stages}')
        if period_relaxation_percent != None:
            command.append(f'--period_relaxation_percent={period_relaxation_percent}')

    command_str = " ".join(command)
    try:
        result = subprocess.run(command_str, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
        result.check_returncode()  # This will raise an exception if the return code was non-zero
        print("Scheduling Run Done.")
    except subprocess.CalledProcessError as e:
        print("An error occurred while running the command.")
        print("Error message:", e.stderr)
    return

def get_graph_with_scheduling(output_schedule_ir_path, schedule_result_path):
    print("Reading Scheduling Result")
    G_schedule, register_count = ReadScheduleIR(output_schedule_ir_path)
    schedule_dict, max_stage_latency = read_SDC_pipeline_result(schedule_result_path)
#     print(schedule_dict)
    G_schedule, stage_num = register_SDC_result(G_schedule, schedule_dict)
    print("Result Graph Generation Done")
    return G_schedule, max_stage_latency, stage_num, register_count

# %%
# Define the operations as named tuples
add = namedtuple("add", "x y")
sub = namedtuple("sub", "x y")
mul = namedtuple("mul", "x y")
div = namedtuple("div", "x y")
shll = namedtuple("shll", "x y")  # Bitshift left
shrl = namedtuple("shrl", "x y")  # Bitshift right
not_ = namedtuple("not_", "x")    # Bitwise NOT
neg = namedtuple("neg", "x")      # Negation

# Evaluation function
def eval_ops(car, cdr):
    try:
        if isinstance(car, (int, float)):
            return car

        if len(cdr) == 0:
            return None

        op = car
        args = cdr

        a = args[0]
        if op == not_:
            return ~a
        if op == neg:
            return -a

        b = args[1]
        if op == add:
            return a + b
        if op == sub:
            return a - b
        if op == mul:
            return a * b
        if op == div and b != 0:
            return a / b
        if op == shll:
            return a << b
        if op == shrl:
            return a >> b

    except:
        pass

    return None

# Rewrite rules
a, b, c = vars("a b c")  # Variables for rewrite rules

list_rules: List[List[Any]] = [
    # DAC paper rules
    ["mul_associativity", mul(mul(a, b), c), mul(b, mul(a, c))],
    ["add_associativity", add(add(a, b), c), add(b, add(a, c))],
    ["mul_distributivity", mul(a, add(b, c)), add(mul(a, b), mul(a, c))],
    ["sum_same", add(a, a), mul(a, 2)],
    ["mul_sum_same", add(mul(a, b), b), mul(add(a, 1), b)],
    ["sub_to_neg", sub(a, b), add(a, neg(b))],
    ["mul_by_two", mul(a, 2), shll(a, 1)],
    ["merge_left_shift", shll(shll(a, b), c), shll(a, add(b, c))],
    ["merge_right_shift", shrl(shrl(a, b), c), shrl(a, add(b, c))],
    ["neg_to_not", neg(a), add(not_(a), 1)],
    
    # Basic arithmetic rules
    ["comm_add", add(a, b), add(b, a)],
    ["comm_mul", mul(a, b), mul(b, a)],
    ["zero_add", add(a, 0), a],
    ["zero_mul", mul(a, 0), 0],
    ["one_mul", mul(a, 1), a],
    ["sub_zero", sub(a, 0), a],
    ["neg", neg(a), sub(0, a)],

    # Bitwise rules
    ["shll_zero", shll(a, 0), a],
    ["shrl_zero", shrl(a, 0), a],
    ["not_not", not_(not_(a)), a],
    
    
]

# Convert list rules into rewrites
rules = [Rewrite(frm, to, name) for name, frm, to in list_rules]

# Function to check if two expressions are equivalent
def is_equal(expr_a, expr_b, iters=5):
    egraph = EGraph(eval_ops)
    id_a = egraph.add(expr_a)
    id_b = egraph.add(expr_b)
    egraph.run(rules, iters)
    return egraph.equiv(id_a, id_b)

# def get_egraph_in_range(expr, min_iters=0, max_iters=1000):
#     expr_list = []
#     # Create an EGraph with the evaluation function
#     egraph = EGraph(eval_ops)

#     # Add the expression to the e-graph
#     expr_id = egraph.add(expr)
       
#     # Run the e-graph with the rewrite rules     
        
#     for cur_iters in range(min_iters, max_iters):
#         egraph.run(rules, cur_iters)
#         cur_expr = egraph.extract(expr_id)
#         if cur_expr in expr_list:
#             pass
#         else:
#             expr_id = egraph.add(cur_expr)
#             expr_list.append(cur_expr)
        
#     return expr_list
egraph = EGraph(eval_ops)
def get_egraph_in_range(expr, max_iters=5):
    expr_list = []
    expr_id = egraph.add(expr)

    for i in range(max_iters):
        egraph.run(rules, 1)  # Run for one iteration
        cur_expr = egraph.extract(expr_id)
        
        if cur_expr not in expr_list:
            expr_list.append(cur_expr)
            expr_id = egraph.add(cur_expr)  # Add current expression for further rewrites

    return expr_list
a = "a"

def test_sum_same():
    expr_a = add(a, a)
    expr_b = mul(a, 2)
    assert is_equal(expr_a, expr_b)

test_sum_same()
expr_text = add(a, a)
print(get_egraph_in_range(expr_text))
# Out:
# [add(x='a', y='a')]

# %%
# gen_json_from_ir("/home/miao/xls/work_space/EGraphUnitTest/all_unit_test.ir", "/home/miao/xls/work_space/EGraphUnitTest/all_unit_test.json")

# %%
def remove_entries(operand_list, to_remove):
    return [op for op in operand_list if op not in to_remove]

def traverse_graph(G, start_node, processed_nodes):
# This function takes in a graph and partitions it to the largest legal rewrite batch
# If a node is not in the allowed list, it is discarded.
    allowed_operations = ["add", "umul", "smul", "shll", "shrl", "not", "neg", "sub", "udiv", "sdiv"] # "literal",
    # Initialize the batch list
    batch = []

    # Create a set to keep track of visited nodes
    visited = set()

    # Traverse the graph
    stack = [start_node]
    while stack:
#         print(stack)
        current = stack.pop()
        current_op_type = G.nodes[current]['OperationType']

        # Check if the current node's operation is allowed
        if current_op_type in allowed_operations:
            # Add the current node to the batch and mark as visited
            batch.append(current)
            visited.add(current)

            for parent in G.predecessors(current):
                # Check if all children of the parent are either visited or disallowed
                all_children_allowed = all(
                    child in visited # or G.nodes[child].get('OperationType', None) not in allowed_operations
                    for child in G.successors(parent)
                )

                if all_children_allowed and parent not in processed_nodes and parent not in visited:
                    stack.append(parent)
    if len(batch) == 1 and G.nodes[batch[0]]['OperationType'] == 'literal':
        batch = []
    return batch

def get_expr_from_batch(G, batch):
    N = len(batch)
    max_loop_count = N * (N + 1) // 2
    batch_queue = deque(batch)
    visited_dict = {}
    loop_count = 0
    cur_expr = None
    is_unsigned = True
    while batch_queue:
        cur_expr = None
        cur_node = batch_queue.pop()
        # If all operands are not in the batch waiting the be handled, or they have been vistied before
        if all(operand not in batch or operand in visited_dict for operand in G.nodes[cur_node]['Operands']):
            if G.nodes[cur_node]['OperationType'] == 'literal':
                visited_dict[G.nodes[cur_node]['OperationName']] = str(G.nodes[cur_node]['Value'])
            else:
                cur_expr = G.nodes[cur_node]['OperationType'] + "("
                for operand in G.nodes[cur_node]['Operands']:
                    # If the operand belongs to a processed expr, use it. Otherwise use the operand as string
                    if operand in visited_dict.keys():
                        cur_expr = cur_expr + visited_dict[operand] + ","
                    else:
                        cur_expr = cur_expr + "'" + operand + "'" + ","
                cur_expr = cur_expr[:-1] + ")"
                visited_dict[G.nodes[cur_node]['OperationName']] = cur_expr
            
            if G.nodes[cur_node]['OperationType'] in ["neg", "smul", "sdiv"]:
                is_unsigned = False
            
        else:
            batch_queue.appendleft(cur_node)
            
        if loop_count > max_loop_count:
            break
        else:
            loop_count += 1
    
    # Handle sign mapping, handle not mapping
    cur_expr = cur_expr.replace("umul", "mul").replace("smul", "mul")
    cur_expr = cur_expr.replace("udiv", "div").replace("sdiv", "div")
    cur_expr = cur_expr.replace("not", "not_")
    if len(batch_queue) == 0: 
        # Return the one with the most dependency
        return cur_expr, is_unsigned
    else:
        print("[ERROR] Unresolved dependency in batch to expr generation")
        return None, None
    
    return None, None

def gen_json_from_expr_recursive(G, expr, operation_mapping, bit_width, nodes_involved_dict=None, counter=None):
    if counter is None:
        counter = 0
    if nodes_involved_dict is None:
        nodes_involved_dict = {}
    
    match = re.search(r'\b(\w+)\(([^()]+)\)', expr)
    if not match:
        return nodes_involved_dict, expr

    operation_type, operands = match.groups()
    operation_name = 'auto_gen'+str(counter)

    # Replace the innermost expression with the placeholder
    new_expr = expr.replace(match.group(0), operation_name)
#     print("OpType: ", operation_type, "; Operands: ",operands)
#     print("Iter:", counter, "expr: ",new_expr)
    
    
    # Handle each node:
    nodes_involved_dict, counter = handle_node_generation(G, operation_type, operands, operation_name, bit_width, nodes_involved_dict, operation_mapping, counter)
    return gen_json_from_expr_recursive(G, new_expr, operation_mapping, bit_width, nodes_involved_dict, counter+1)


# Node(name=None, bitwidth=None, operation=None, operands=None, 
#                  idNum=None, value=None, pos=None, FuncIO=None, start=None, width=None)

def handle_node_generation(G, operation_type, operands, operation_name, bit_width, nodes_involved_dict, operation_mapping, counter):
    operands_list = operands.split(',')
    new_node_operands = []
    NewNode = None
    for cur_operand in operands_list:
        cur_operand = cur_operand.split("=")[-1]
        # First setup operand list
        if cur_operand.strip("'").strip(" ").isdigit():
            counter += 1
            # Handle pure digit, generate literal from them
            try:
                cur_value = int(cur_operand.strip("'").strip(" "))
            except ValueError:
                cur_value = float(cur_operand.strip("'").strip(" "))
                
            # Update the bitwidth to the nearest power of 2 if necessary
            required_bitwidth = ceil(log2(abs(cur_value) + 1)) if cur_value >= 0 else ceil(log2(abs(cur_value)))
#             print(cur_value, ' ', bit_width, " " , required_bitwidth)

            if required_bitwidth > bit_width:
                bit_width = 2 ** ceil(log2(required_bitwidth))    
            NewLiteralNode = node_to_dict(Node('auto_gen'+str(counter), bit_width, 'Literal', value=cur_value))
            NewLiteralNode["ReplaceSelfWith"] = 'Gen'       
            nodes_involved_dict['auto_gen'+str(counter)] = NewLiteralNode
            new_node_operands.append('auto_gen'+str(counter))
        else:
            new_node_operands.append(cur_operand.strip("'"))
    #Now generate new node:
    NewNode = node_to_dict(Node(operation_name, bit_width, operation_mapping[operation_type], new_node_operands))
    NewNode["ReplaceSelfWith"] = 'Gen'
    nodes_involved_dict[operation_name] = NewNode
    return nodes_involved_dict, counter

# %%
def gen_json_from_ir(ir_input_path, json_output_path, rewrite_rule = "NoRule"):
    # This function takes in ir file and generate json instruction based on e-graph
    
    TopFunctionName = None
    with open(ir_input_path, 'r') as f:
        ir_content = f.read()
        ir_dict = slice_ir_by_function(ir_content)

    #     print(ir_content)

    FuncNodeDict = {}
    for fn_name, fn_content in ir_dict.items():
        NodeDict = {}
        Lines = ParseIRFile(fn_content)
        for Line in Lines:    
            NodeList = LineToDict(Line)
            if NodeList != None:
                for NodeObj in NodeList:
                    NodeDict[NodeObj.name] = NodeObj
            if "top" in Line:
                TopFunctionName = fn_name
        FuncNodeDict[fn_name] = NodeDict
    SubCounter = 0
    NodeCounter = 0
    JsonOutDict = {}
#     print(FuncNodeDict)


    ## The following code reads digraph and partitions them into legal rewrite batches
    graph_by_function = {}
    sorted_nodes_by_function = {}

    for fn_name, fn_nodes in FuncNodeDict.items():
        G = nx.DiGraph()
        G = DictToGraph(G, fn_nodes)
        graph_by_function[fn_name] = G
        
#         nx.draw(G, with_labels=True, font_weight='bold')

        # Check if the graph is a DAG
        if nx.is_directed_acyclic_graph(G):
            sorted_nodes = list(nx.topological_sort(G))
            sorted_nodes_by_function[fn_name] = sorted_nodes[::-1]
        else:
            sorted_nodes_by_function[fn_name] = None
            print(f"[Warning] Graph for function {fn_name} is not a DAG. Topological sorting cannot be performed.")

#         print(f"Function: {fn_name}")
#         print("Batches of nodes:", sorted_nodes_by_function[fn_name])   


    rewrite_batch_by_function = {}
    processed_nodes = set()

    for fn_name, nodes in sorted_nodes_by_function.items():
        G = graph_by_function[fn_name]
        rewrite_batch_by_function[fn_name] = []

        temp_nodes = nodes.copy()
        cur_index = 0
        while temp_nodes and cur_index < len(temp_nodes):
            start_node = temp_nodes[cur_index]
            cur_batch = traverse_graph(G, start_node, processed_nodes)
#             print("Current  Batch: ", cur_batch)
            if cur_batch != []:
                rewrite_batch_by_function[fn_name].append(cur_batch)
                for node in cur_batch:
                    processed_nodes.add(node)
                    if node in temp_nodes:
                        temp_nodes.remove(node)
            else:
                cur_index += 1

#         print(f"Function: {fn_name}")
#         print("Batches of nodes:", rewrite_batch_by_function[fn_name])

    ## The following code takes each batch, and generate expression for e-graph search
    rewrite_candidate_by_function = {}
    for fn_name, batch_list in rewrite_batch_by_function.items():
        G = graph_by_function[fn_name]
        rewrite_candidate_by_function[fn_name] = {}
        rewrite_candidate_by_function[fn_name]['is_unsigned'] = []
        rewrite_candidate_by_function[fn_name]['rewrite_candidates'] = []
        for batch in batch_list:
            batch_expr, is_unsigned = get_expr_from_batch(G, batch)
            print("FunctionName: ", fn_name)
            print("Input Expr: ", batch_expr)
            cur_candidates = get_egraph_in_range(eval(batch_expr))
            rewrite_candidate_by_function[fn_name]['is_unsigned'].append(is_unsigned)
            rewrite_candidate_by_function[fn_name]['rewrite_candidates'] .append(cur_candidates)
            print(cur_candidates)
    # print(rewrite_candidate_by_function)

    operation_mapping_unsigned = {"add" : "kAdd",
                                  "mul" : "kUMul",
                                  "div" : "kUDiv",
                                  "sub" : "kSub",
                                "literal" : "Literal",
                                 "neg" : "kNeg",
                                 "shll" : "kShll",
                                 "shrl" : "kShrl",
                                 "not_" : "kNot"}

    operation_mapping_signed = {"add" : "kAdd",
                                  "mul" : "kSMul",
                                  "div" : "kSDiv",
                                  "sub" : "kSub",
                                "literal" : "Literal",
                                 "neg" : "kNeg",
                                 "shll" : "kShll",
                                 "shrl" : "kShrl",
                                 "not_" : "kNot"}
    json_dict = {}
    counter = 0
    for fn_name, all_rewrite_candidates_dict in rewrite_candidate_by_function.items():
        G = graph_by_function[fn_name]
        for i in range(len(all_rewrite_candidates_dict['rewrite_candidates'])):
            cur_rewrite_candidate = all_rewrite_candidates_dict['rewrite_candidates'][i]
            
            #First we initialize the dictionary
            json_dict[str(counter)] = {}
            json_dict[str(counter)]["FuncName"] = fn_name

            #Then, find bitwidth and if the variables are signed, and assign operator mapping
            cur_is_unsigned = all_rewrite_candidates_dict['is_unsigned'][i]
            bit_width = 0
            for cur_node_name in rewrite_batch_by_function[fn_name][i]:
                cur_bit_width = G.nodes[cur_node_name]['BitWidth']
                if cur_bit_width > bit_width:
                    bit_width = cur_bit_width
                    
            if cur_is_unsigned:
                cur_operation_mapping = operation_mapping_unsigned
            else:
                cur_operation_mapping = operation_mapping_signed
                
                
            # Now we call our selector to get a best rewrite
            if rewrite_rule == "NoRule":
                rewrite_expr = cur_rewrite_candidate[-1]
            elif rewrite_rule == "NaivePick":
                rewrite_expr = naive_pick(G, cur_rewrite_candidate, bit_width, cur_operation_mapping)
            else:
                rewrite_expr = cur_rewrite_candidate[-1]  
            
            # print("FunctionName: ",fn_name)
            print("Rewrite Expr", rewrite_expr)

            #Next, handle node generation
            nodes_involved_dict, out_node_name = gen_json_from_expr_recursive(G, str(rewrite_expr), cur_operation_mapping, bit_width)

            #Next, handle node elimination
            for old_node_id in rewrite_batch_by_function[fn_name][i]:
                nodes_involved_dict[G.nodes[old_node_id]['OperationName']] = G.nodes[old_node_id]
                nodes_involved_dict[G.nodes[old_node_id]['OperationName']]['ReplaceSelfWith'] = 'Kill'

            #Next, handle batch output replacement
            #ToDo: we need to verify the first is always the output of the batch
            nodes_involved_dict[G.nodes[rewrite_batch_by_function[fn_name][i][0]]['OperationName']] = G.nodes[rewrite_batch_by_function[fn_name][i][0]]
            nodes_involved_dict[G.nodes[rewrite_batch_by_function[fn_name][i][0]]['OperationName']]['ReplaceSelfWith'] = str(out_node_name)

            json_dict[str(counter)]["NodesInvolved"] = list(nodes_involved_dict.values())
            counter += 1
            
#             print(nodes_involved_dict)

    with open(json_output_path, 'w') as json_file:
            json.dump(json_dict, json_file, indent=4)  
    return G, TopFunctionName

# %%
def egraph_flow(ir_input_path, delay_model='sky130', 
               Schedule_Method="SDC", selector="NoRule", clock_period_ps=None, clock_margin_precent=None, 
               pipeline_stages=None, period_relaxation_percent=None):
    
    command_executable = '/home/miao/xls/bazel-bin/xls/tools/RL_main'
    ir_unify_name_out = ir_input_path.replace('.ir','.unify.ir')
    json_output_path = ir_input_path.replace('.ir','.json')
    ir_output_path = ir_input_path.replace('.ir','_substitution.ir')
    schedule_result_path = ir_input_path.replace('.ir', '_schedule.txt')
    output_verilog_path = json_output_path.replace(".json", ".v")
    output_schedule_ir_path = ir_output_path.replace(".ir", "_schedule.ir")
    
    run_unify_name(ir_input_path, ir_unify_name_out)
    #Get rewrite json file from IR and selector model
    G, TopFunctionName = gen_json_from_ir(ir_unify_name_out, json_output_path, rewrite_rule=selector)
    #Run cc rewriter to implement the rewrite
    run_rewriter(command_executable, ir_unify_name_out, json_output_path, ir_output_path)
    #Run SDC with the new IR and generate result.
    run_sdc_scheduler(ir_output_path, output_verilog_path, schedule_result_path, output_schedule_ir_path, 
                      delay_model, TopFunctionName, clock_period_ps, clock_margin_precent, 
                      pipeline_stages, period_relaxation_percent)
    #Collect the scheduling result to a graph
    G_schedule, max_stage_latency, stage_num, register_count = get_graph_with_scheduling(output_schedule_ir_path, schedule_result_path)
    
    return G_schedule, max_stage_latency, stage_num, register_count

# %%
# gen_json_from_ir("/home/miao/xls/work_space/EGraphUnitTest/all_unit_test.ir", "/home/miao/xls/work_space/EGraphUnitTest/all_unit_test.json")

# %%
# egraph_flow("/home/miao/xls/work_space/EGraphTest/test.opt.ir", clock_period_ps = 1000)
egraph_flow("/home/miao/xls/work_space/EGraphUnitTest/all_unit_test.ir", clock_period_ps = 1000)
# egraph_flow("/home/miao/xls/work_space/Sha256/sha256.opt.ir", clock_period_ps = 3000, selector="NaivePick")
# egraph_flow("/home/miao/xls/work_space/adler32/adler32.opt.ir", clock_period_ps = 25825)
# Out:
# Name Unification Run Done.
# FunctionName:  AddAssociativity
# Input Expr:  add(add('z1','x1'),'y1')
# [add(x=add(x='z1', y='x1'), y='y1'), add(x='x1', y=add(x='z1', y='y1'))]
# FunctionName:  Unsigned_MulAssociativity
# Input Expr:  mul(mul('z2','x2'),'y2')
# [mul(x=mul(x='z2', y='x2'), y='y2'), mul(x='x2', y=mul(x='z2', y='y2'))]
# FunctionName:  MulDistribution
# Input Expr:  mul(add('z3','x3'),'y3')
# [mul(x=add(x='z3', y='x3'), y='y3')]
# FunctionName:  SumSame
# Input Expr:  add('x4','x4')
# [add(x='x4', y='x4'), mul(x='x4', y=2)]
# FunctionName:  MulSumSame
# Input Expr:  add(mul('x5','y5'),'y5')
# [add(x=mul(x='x5', y='y5'), y='y5'), mul(x=add(x='x5', y=1), y='y5'), mul(x='y5', y=add(x='x5', y=1)), mul(x='y5', y=add(x=1, y='x5'))]
# FunctionName:  MulSumSame
# Input Expr:  add(mul('x5','y5'),'z5')
# [add(x=mul(x='x5', y='y5'), y='z5')]
# FunctionName:  Signed_MulAssociativity
# Input Expr:  mul(mul('z6','x6'),'y6')
# [mul(x=mul(x='z6', y='x6'), y='y6'), mul(x='x6', y=mul(x='z6', y='y6'))]
# FunctionName:  SubToNeg
# Input Expr:  sub('x7','y7')
# [sub(x='x7', y='y7')]
# FunctionName:  MulByTwo
# Input Expr:  mul('x8','literal.17')
# [mul(x='x8', y='literal.17')]
# FunctionName:  MulByTwo
# Input Expr:  mul('x8','literal.15')
# [mul(x='x8', y='literal.15')]
# FunctionName:  MergeLeftRightShift
# Input Expr:  shrl(shrl('x9','y9'),'z9')
# [shrl(x=shrl(x='x9', y='y9'), y='z9'), shrl(x='x9', y=add(x='y9', y='z9'))]
# FunctionName:  MergeLeftRightShift
# Input Expr:  shll(shll('x9','y9'),'z9')
# [shll(x=shll(x='x9', y='y9'), y='z9'), shll(x='x9', y=add(x='y9', y='z9'))]
# FunctionName:  NegToNot
# Input Expr:  neg('x10')
# [neg(x='x10')]
# FunctionName:  NotOverConcat
# Input Expr:  not_('concat.25')
# [not_(x='concat.25')]
# FunctionName:  CoreDump
# Input Expr:  add(add(add('z12','x12'),'y12'),'y12')
# [add(x=add(x=add(x='z12', y='x12'), y='y12'), y='y12'), add(x='y12', y=add(x='x12', y=add(x='z12', y='y12'))), add(x='z12', y=add(x='x12', y=mul(x='y12', y=2)))]
# FunctionName:  MoreThanOneRef
# Input Expr:  add('concat.32','concat.33')
# [add(x='concat.32', y='concat.33')]
# FunctionName:  MoreThanOneRef
# Input Expr:  add('add.30','y13')
# [add(x='add.30', y='y13')]
# FunctionName:  MoreThanOneRef
# Input Expr:  add('z13','x13')
# [add(x='z13', y='x13')]
# FunctionName:  UnsupportRef
# Input Expr:  add('literal.36','bit_slice.37')
# [add(x='literal.36', y='bit_slice.37')]
# FunctionName:  UnsupportRef
# Input Expr:  add('z14','x14')
# [add(x='z14', y='x14')]
#
# Running Standalone Rewriter
# Rewriter Run Done
# Scheduling Run Done.
# Reading Scheduling Result
# Result Graph Generation Done
# (<networkx.classes.digraph.DiGraph at 0x7f994d55f520>, 853, 2, 6)

# %%
path = "/home/miao/xls/work_space/Sha256/sha256.opt.ir"
# path = "/home/miao/xls/work_space/MaxTimeTest/test.opt.ir"
G, max_stage_latency, stage_num, register_count = get_sdc_from_graph(path, clock_period_ps=4000)
print("Number Of Nodes Before: ", len(G.nodes()), "Reg count: ", register_count)
print("Max Pipeline Latency Before: ", max_stage_latency, "stages:" , stage_num)
G, max_stage_latency, stage_num, register_count = egraph_flow(path, clock_period_ps = 4000, selector="NaivePick")
print("Number Of Nodes After: ", len(G.nodes()), "Reg count: ", register_count)
print("Max Pipeline Latency After: ", max_stage_latency, "stages:" , stage_num)
# Out:
# Name Unification Run Done.
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.22490','add.50061'),'literal.51591')
# [add(x=add(x='add.22490', y='add.50061'), y='literal.51591'), add(x='add.50061', y=add(x='add.22490', y='literal.51591'))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.50061','concat.34917'),add('xor.22746','literal.51594'))
# [add(x=add(x='add.50061', y='concat.34917'), y=add(x='xor.22746', y='literal.51594')), add(x='concat.34917', y=add(x='add.50061', y=add(x='xor.22746', y='literal.51594')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.22491','concat.34879'),add('xor.22734','add.17804')),add(add('concat.30112','add.18245'),'concat.51566'))
# [add(x=add(x=add(x='add.22491', y='concat.34879'), y=add(x='xor.22734', y='add.17804')), y=add(x=add(x='concat.30112', y='add.18245'), y='concat.51566')), add(x=add(x='xor.22734', y='add.17804'), y=add(x=add(x='add.22491', y='concat.34879'), y=add(x=add(x='concat.30112', y='add.18245'), y='concat.51566'))), add(x=add(x=add(x='add.22491', y='concat.34879'), y='add.17804'), y=add(x='xor.22734', y=add(x='concat.30112', y=add(x='add.18245', y='concat.51566')))), add(x='concat.34879', y=add(x=add(x=add(x='concat.30112', y='add.18245'), y='concat.51566'), y=add(x='xor.22734', y=add(x='add.22491', y='add.17804')))), add(x=add(x='concat.34879', y=add(x='concat.51566', y=add(x='add.22491', y='add.18245'))), y=add(x=add(x='add.17804', y='concat.30112'), y='xor.22734')), add(x='add.22491', y=add(x='concat.34879', y=add(x=add(x='xor.22734', y='add.17804'), y=add(x=add(x='concat.30112', y='add.18245'), y='concat.51566')))), add(x='concat.34879', y=add(x=add(x='add.17804', y='concat.30112'), y=add(x='add.22491', y=add(x='concat.51566', y=add(x='xor.22734', y='add.18245')))))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51359','literal.51401')
# [add(x='bit_slice.51359', y='literal.51401')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22685','literal.51595')
# [add(x='add.22685', y='literal.51595')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.50131',add('concat.34841','xor.22681'))
# [add(x='add.50131', y=add(x='concat.34841', y='xor.22681'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22425','add.50131')
# [add(x='add.22425', y='add.50131')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.22426','concat.34803'),add('xor.22669','add.17755')),add(add('concat.30050','add.18196'),add('concat.30067','literal.23641')))
# [add(x=add(x=add(x='add.22426', y='concat.34803'), y=add(x='xor.22669', y='add.17755')), y=add(x=add(x='concat.30050', y='add.18196'), y=add(x='concat.30067', y='literal.23641'))), add(x=add(x='xor.22669', y='add.17755'), y=add(x=add(x='add.22426', y='concat.34803'), y=add(x='add.18196', y=add(x='concat.30050', y=add(x='concat.30067', y='literal.23641'))))), add(x='add.22426', y=add(x=add(x='xor.22669', y='add.17755'), y=add(x='concat.34803', y=add(x=add(x='concat.30050', y='add.18196'), y=add(x='concat.30067', y='literal.23641'))))), add(x='concat.34803', y=add(x='add.22426', y=add(x=add(x='concat.30050', y='add.18196'), y=add(x=add(x='xor.22669', y='add.17755'), y=add(x='concat.30067', y='literal.23641'))))), add(x='concat.34803', y=add(x=add(x=add(x='concat.30050', y=add(x='add.22426', y='add.18196')), y=add(x='add.17755', y=add(x='concat.30067', y='literal.23641'))), y='xor.22669')), add(x='add.22426', y=add(x='add.17755', y=add(x='concat.34803', y=add(x='concat.30050', y=add(x='xor.22669', y=add(x='add.18196', y=add(x='concat.30067', y='literal.23641'))))))), add(x='add.22426', y=add(x='add.18196', y=add(x=add(x='concat.34803', y='concat.30050'), y=add(x='xor.22669', y=add(x='add.17755', y=add(x='concat.30067', y='literal.23641'))))))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51349','literal.51598')
# [add(x='bit_slice.51349', y='literal.51598')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22621','literal.23171')
# [add(x='add.22621', y='literal.23171')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22617',add('concat.34765','xor.22616'))
# [add(x='add.22617', y=add(x='concat.34765', y='xor.22616'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22360','add.22617')
# [add(x='add.22360', y='add.22617')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.22361','concat.34727'),'xor.22604'),add('add.18490','literal.23634'))
# [add(x=add(x=add(x='add.22361', y='concat.34727'), y='xor.22604'), y=add(x='add.18490', y='literal.23634')), add(x='xor.22604', y=add(x=add(x='add.22361', y='concat.34727'), y=add(x='add.18490', y='literal.23634'))), add(x='add.22361', y=add(x='xor.22604', y=add(x='concat.34727', y=add(x='add.18490', y='literal.23634')))), add(x=add(x='literal.23634', y=add(x='concat.34727', y='xor.22604')), y=add(x='add.22361', y='add.18490'))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51354','literal.51597')
# [add(x='bit_slice.51354', y='literal.51597')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22556','literal.23656')
# [add(x='add.22556', y='literal.23656')]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.22556')
# [not_(x='add.22556')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51404',add('concat.34689','xor.22551'))
# [add(x='add.51404', y=add(x='concat.34689', y='xor.22551'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22295','add.51404')
# [add(x='add.22295', y='add.51404')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.22296','concat.34651'),add('xor.22539','concat.51343'))
# [add(x=add(x='add.22296', y='concat.34651'), y=add(x='xor.22539', y='concat.51343')), add(x='concat.34651', y=add(x='add.22296', y=add(x='xor.22539', y='concat.51343')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.22491')
# [not_(x='add.22491')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51407',add('concat.34613','xor.22486'))
# [add(x='add.51407', y=add(x='concat.34613', y='xor.22486'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22230','add.51407')
# [add(x='add.22230', y='add.51407')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.22231','concat.34575'),add('xor.22474','concat.51338'))
# [add(x=add(x='add.22231', y='concat.34575'), y=add(x='xor.22474', y='concat.51338')), add(x='concat.34575', y=add(x='add.22231', y=add(x='xor.22474', y='concat.51338')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.22426')
# [not_(x='add.22426')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51410',add('concat.34537','xor.22421'))
# [add(x='add.51410', y=add(x='concat.34537', y='xor.22421'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22165','add.51410')
# [add(x='add.22165', y='add.51410')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.22166','concat.34499'),add('xor.22409','concat.51333'))
# [add(x=add(x='add.22166', y='concat.34499'), y=add(x='xor.22409', y='concat.51333')), add(x='concat.34499', y=add(x='add.22166', y=add(x='xor.22409', y='concat.51333')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.22361')
# [not_(x='add.22361')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22357',add('concat.34461','xor.22356'))
# [add(x='add.22357', y=add(x='concat.34461', y='xor.22356'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22100','add.22357')
# [add(x='add.22100', y='add.22357')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.22101','concat.34423'),'xor.22344'),add('add.18294','literal.23606'))
# [add(x=add(x=add(x='add.22101', y='concat.34423'), y='xor.22344'), y=add(x='add.18294', y='literal.23606')), add(x='xor.22344', y=add(x=add(x='add.22101', y='concat.34423'), y=add(x='add.18294', y='literal.23606'))), add(x='add.22101', y=add(x='xor.22344', y=add(x='concat.34423', y=add(x='add.18294', y='literal.23606')))), add(x=add(x='literal.23606', y=add(x='concat.34423', y='xor.22344')), y=add(x='add.22101', y='add.18294'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.22296')
# [not_(x='add.22296')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51413',add('concat.34385','xor.22291'))
# [add(x='add.51413', y=add(x='concat.34385', y='xor.22291'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22035','add.51413')
# [add(x='add.22035', y='add.51413')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.22036','concat.34347'),add('xor.22279','concat.51328'))
# [add(x=add(x='add.22036', y='concat.34347'), y=add(x='xor.22279', y='concat.51328')), add(x='concat.34347', y=add(x='add.22036', y=add(x='xor.22279', y='concat.51328')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.22231')
# [not_(x='add.22231')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22227',add('concat.34309','xor.22226'))
# [add(x='add.22227', y=add(x='concat.34309', y='xor.22226'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21970','add.22227')
# [add(x='add.21970', y='add.22227')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.21971','concat.34271'),'xor.22214'),add('add.18196','literal.23592'))
# [add(x=add(x=add(x='add.21971', y='concat.34271'), y='xor.22214'), y=add(x='add.18196', y='literal.23592')), add(x='xor.22214', y=add(x=add(x='add.21971', y='concat.34271'), y=add(x='add.18196', y='literal.23592'))), add(x='add.21971', y=add(x='xor.22214', y=add(x='concat.34271', y=add(x='add.18196', y='literal.23592')))), add(x=add(x='literal.23592', y=add(x='concat.34271', y='xor.22214')), y=add(x='add.21971', y='add.18196'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.22166')
# [not_(x='add.22166')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22162',add('concat.34233','xor.22161'))
# [add(x='add.22162', y=add(x='concat.34233', y='xor.22161'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21905','add.22162')
# [add(x='add.21905', y='add.22162')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.21906','concat.34195'),'xor.22149'),add('add.18147','literal.23585'))
# [add(x=add(x=add(x='add.21906', y='concat.34195'), y='xor.22149'), y=add(x='add.18147', y='literal.23585')), add(x='xor.22149', y=add(x=add(x='add.21906', y='concat.34195'), y=add(x='add.18147', y='literal.23585'))), add(x='add.21906', y=add(x='xor.22149', y=add(x='concat.34195', y=add(x='add.18147', y='literal.23585')))), add(x=add(x='literal.23585', y=add(x='concat.34195', y='xor.22149')), y=add(x='add.21906', y='add.18147'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.22101')
# [not_(x='add.22101')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51416',add('concat.34157','xor.22096'))
# [add(x='add.51416', y=add(x='concat.34157', y='xor.22096'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21840','add.51416')
# [add(x='add.21840', y='add.51416')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.21841','concat.34119'),add('xor.22084','concat.51323'))
# [add(x=add(x='add.21841', y='concat.34119'), y=add(x='xor.22084', y='concat.51323')), add(x='concat.34119', y=add(x='add.21841', y=add(x='xor.22084', y='concat.51323')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.22036')
# [not_(x='add.22036')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22032',add('concat.34081','xor.22031'))
# [add(x='add.22032', y=add(x='concat.34081', y='xor.22031'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21775','add.22032')
# [add(x='add.21775', y='add.22032')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.21776','concat.34043'),'xor.22019'),add('add.18049','literal.23571'))
# [add(x=add(x=add(x='add.21776', y='concat.34043'), y='xor.22019'), y=add(x='add.18049', y='literal.23571')), add(x='xor.22019', y=add(x=add(x='add.21776', y='concat.34043'), y=add(x='add.18049', y='literal.23571'))), add(x='add.21776', y=add(x='xor.22019', y=add(x='concat.34043', y=add(x='add.18049', y='literal.23571')))), add(x=add(x='literal.23571', y=add(x='concat.34043', y='xor.22019')), y=add(x='add.21776', y='add.18049'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.21971')
# [not_(x='add.21971')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21967',add('concat.34005','xor.21966'))
# [add(x='add.21967', y=add(x='concat.34005', y='xor.21966'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21710','add.21967')
# [add(x='add.21710', y='add.21967')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.21711','concat.33967'),'xor.21954'),add('add.18000','literal.23564'))
# [add(x=add(x=add(x='add.21711', y='concat.33967'), y='xor.21954'), y=add(x='add.18000', y='literal.23564')), add(x='xor.21954', y=add(x=add(x='add.21711', y='concat.33967'), y=add(x='add.18000', y='literal.23564'))), add(x='add.21711', y=add(x='xor.21954', y=add(x='concat.33967', y=add(x='add.18000', y='literal.23564')))), add(x=add(x='literal.23564', y=add(x='concat.33967', y='xor.21954')), y=add(x='add.21711', y='add.18000'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.21906')
# [not_(x='add.21906')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51419',add('concat.33929','xor.21901'))
# [add(x='add.51419', y=add(x='concat.33929', y='xor.21901'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21645','add.51419')
# [add(x='add.21645', y='add.51419')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.21646','concat.33891'),add('xor.21889','concat.51318'))
# [add(x=add(x='add.21646', y='concat.33891'), y=add(x='xor.21889', y='concat.51318')), add(x='concat.33891', y=add(x='add.21646', y=add(x='xor.21889', y='concat.51318')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.21841')
# [not_(x='add.21841')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51422',add('concat.33853','xor.21836'))
# [add(x='add.51422', y=add(x='concat.33853', y='xor.21836'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21580','add.51422')
# [add(x='add.21580', y='add.51422')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.21581','concat.33815'),add('xor.21824','concat.51313'))
# [add(x=add(x='add.21581', y='concat.33815'), y=add(x='xor.21824', y='concat.51313')), add(x='concat.33815', y=add(x='add.21581', y=add(x='xor.21824', y='concat.51313')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.21776')
# [not_(x='add.21776')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51425',add('concat.33777','xor.21771'))
# [add(x='add.51425', y=add(x='concat.33777', y='xor.21771'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21515','add.51425')
# [add(x='add.21515', y='add.51425')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.21516','concat.33739'),add('xor.21759','concat.51308'))
# [add(x=add(x='add.21516', y='concat.33739'), y=add(x='xor.21759', y='concat.51308')), add(x='concat.33739', y=add(x='add.21516', y=add(x='xor.21759', y='concat.51308')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.21711')
# [not_(x='add.21711')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51428',add('concat.33701','xor.21706'))
# [add(x='add.51428', y=add(x='concat.33701', y='xor.21706'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21450','add.51428')
# [add(x='add.21450', y='add.51428')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.21451','concat.33663'),add('xor.21694','concat.51303'))
# [add(x=add(x='add.21451', y='concat.33663'), y=add(x='xor.21694', y='concat.51303')), add(x='concat.33663', y=add(x='add.21451', y=add(x='xor.21694', y='concat.51303')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.
))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21060','add.21317')
# [add(x='add.21060', y='add.21317')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.21061','concat.33207'),'xor.21304'),add('add.17510','literal.23494'))
# [add(x=add(x=add(x='add.21061', y='concat.33207'), y='xor.21304'), y=add(x='add.17510', y='literal.23494')), add(x='xor.21304', y=add(x=add(x='add.21061', y='concat.33207'), y=add(x='add.17510', y='literal.23494'))), add(x='add.21061', y=add(x='xor.21304', y=add(x='concat.33207', y=add(x='add.17510', y='literal.23494')))), add(x=add(x='literal.23494', y=add(x='concat.33207', y='xor.21304')), y=add(x='add.21061', y='add.17510'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.21256')
# [not_(x='add.21256')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21252',add('concat.33169','xor.21251'))
# [add(x='add.21252', y=add(x='concat.33169', y='xor.21251'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20995','add.21252')
# [add(x='add.20995', y='add.21252')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20996','concat.33131'),'xor.21239'),add('add.17461','literal.23487'))
# [add(x=add(x=add(x='add.20996', y='concat.33131'), y='xor.21239'), y=add(x='add.17461', y='literal.23487')), add(x='xor.21239', y=add(x=add(x='add.20996', y='concat.33131'), y=add(x='add.17461', y='literal.23487'))), add(x='add.20996', y=add(x='xor.21239', y=add(x='concat.33131', y=add(x='add.17461', y='literal.23487')))), add(x=add(x='literal.23487', y=add(x='concat.33131', y='xor.21239')), y=add(x='add.20996', y='add.17461'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.21191')
# [not_(x='add.21191')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21187',add('concat.33093','xor.21186'))
# [add(x='add.21187', y=add(x='concat.33093', y='xor.21186'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20930','add.21187')
# [add(x='add.20930', y='add.21187')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20931','concat.33055'),'xor.21174'),add('add.17412','literal.23480'))
# [add(x=add(x=add(x='add.20931', y='concat.33055'), y='xor.21174'), y=add(x='add.17412', y='literal.23480')), add(x='xor.21174', y=add(x=add(x='add.20931', y='concat.33055'), y=add(x='add.17412', y='literal.23480'))), add(x='add.20931', y=add(x='xor.21174', y=add(x='concat.33055', y=add(x='add.17412', y='literal.23480')))), add(x=add(x='literal.23480', y=add(x='concat.33055', y='xor.21174')), y=add(x='add.20931', y='add.17412'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.21126')
# [not_(x='add.21126')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51437',add('concat.33017','xor.21121'))
# [add(x='add.51437', y=add(x='concat.33017', y='xor.21121'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20865','add.51437')
# [add(x='add.20865', y='add.51437')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.20866','concat.32979'),add('xor.21109','concat.51288'))
# [add(x=add(x='add.20866', y='concat.32979'), y=add(x='xor.21109', y='concat.51288')), add(x='concat.32979', y=add(x='add.20866', y=add(x='xor.21109', y='concat.51288')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.21061')
# [not_(x='add.21061')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21057',add('concat.32941','xor.21056'))
# [add(x='add.21057', y=add(x='concat.32941', y='xor.21056'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20800','add.21057')
# [add(x='add.20800', y='add.21057')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20801','concat.32903'),'xor.21044'),add('add.17314','literal.23466'))
# [add(x=add(x=add(x='add.20801', y='concat.32903'), y='xor.21044'), y=add(x='add.17314', y='literal.23466')), add(x='xor.21044', y=add(x=add(x='add.20801', y='concat.32903'), y=add(x='add.17314', y='literal.23466'))), add(x='add.20801', y=add(x='xor.21044', y=add(x='concat.32903', y=add(x='add.17314', y='literal.23466')))), add(x=add(x='literal.23466', y=add(x='concat.32903', y='xor.21044')), y=add(x='add.20801', y='add.17314'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20996')
# [not_(x='add.20996')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51440',add('concat.32865','xor.20991'))
# [add(x='add.51440', y=add(x='concat.32865', y='xor.20991'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20735','add.51440')
# [add(x='add.20735', y='add.51440')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.20736','concat.32827'),add('xor.20979','concat.51283'))
# [add(x=add(x='add.20736', y='concat.32827'), y=add(x='xor.20979', y='concat.51283')), add(x='concat.32827', y=add(x='add.20736', y=add(x='xor.20979', y='concat.51283')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20931')
# [not_(x='add.20931')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20927',add('concat.32789','xor.20926'))
# [add(x='add.20927', y=add(x='concat.32789', y='xor.20926'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20670','add.20927')
# [add(x='add.20670', y='add.20927')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20671','concat.32751'),'xor.20914'),add('add.17216','literal.23452'))
# [add(x=add(x=add(x='add.20671', y='concat.32751'), y='xor.20914'), y=add(x='add.17216', y='literal.23452')), add(x='xor.20914', y=add(x=add(x='add.20671', y='concat.32751'), y=add(x='add.17216', y='literal.23452'))), add(x='add.20671', y=add(x='xor.20914', y=add(x='concat.32751', y=add(x='add.17216', y='literal.23452')))), add(x=add(x='literal.23452', y=add(x='concat.32751', y='xor.20914')), y=add(x='add.20671', y='add.17216'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20866')
# [not_(x='add.20866')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51443',add('concat.32713','xor.20861'))
# [add(x='add.51443', y=add(x='concat.32713', y='xor.20861'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20605','add.51443')
# [add(x='add.20605', y='add.51443')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.20606','concat.32675'),add('xor.20849','concat.51278'))
# [add(x=add(x='add.20606', y='concat.32675'), y=add(x='xor.20849', y='concat.51278')), add(x='concat.32675', y=add(x='add.20606', y=add(x='xor.20849', y='concat.51278')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20801')
# [not_(x='add.20801')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51446',add('concat.32637','xor.20796'))
# [add(x='add.51446', y=add(x='concat.32637', y='xor.20796'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20540','add.51446')
# [add(x='add.20540', y='add.51446')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.20541','concat.32599'),add('xor.20784','concat.51273'))
# [add(x=add(x='add.20541', y='concat.32599'), y=add(x='xor.20784', y='concat.51273')), add(x='concat.32599', y=add(x='add.20541', y=add(x='xor.20784', y='concat.51273')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20736')
# [not_(x='add.20736')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20732',add('concat.32561','xor.20731'))
# [add(x='add.20732', y=add(x='concat.32561', y='xor.20731'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20475','add.20732')
# [add(x='add.20475', y='add.20732')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20476','concat.32523'),'xor.20719'),add('add.17069','literal.23431'))
# [add(x=add(x=add(x='add.20476', y='concat.32523'), y='xor.20719'), y=add(x='add.17069', y='literal.23431')), add(x='xor.20719', y=add(x=add(x='add.20476', y='concat.32523'), y=add(x='add.17069', y='literal.23431'))), add(x='add.20476', y=add(x='xor.20719', y=add(x='concat.32523', y=add(x='add.17069', y='literal.23431')))), add(x=add(x='literal.23431', y=add(x='concat.32523', y='xor.20719')), y=add(x='add.20476', y='add.17069'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20671')
# [not_(x='add.20671')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20667',add('concat.32485','xor.20666'))
# [add(x='add.20667', y=add(x='concat.32485', y='xor.20666'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20410','add.20667')
# [add(x='add.20410', y='add.20667')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20411','concat.32447'),'xor.20654'),add('add.17020','literal.23424'))
# [add(x=add(x=add(x='add.20411', y='concat.32447'), y='xor.20654'), y=add(x='add.17020', y='literal.23424')), add(x='xor.20654', y=add(x=add(x='add.20411', y='concat.32447'), y=add(x='add.17020', y='literal.23424'))), add(x='add.20411', y=add(x='xor.20654', y=add(x='concat.32447', y=add(x='add.17020', y='literal.23424')))), add(x=add(x='literal.23424', y=add(x='concat.32447', y='xor.20654')), y=add(x='add.20411', y='add.17020'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20606')
# [not_(x='add.20606')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20602',add('concat.32409','xor.20601'))
# [add(x='add.20602', y=add(x='concat.32409', y='xor.20601'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20345','add.20602')
# [add(x='add.20345', y='add.20602')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20346','concat.32371'),'xor.20589'),add('add.16971','literal.23417'))
# [add(x=add(x=add(x='add.20346', y='concat.32371'), y='xor.20589'), y=add(x='add.16971', y='literal.23417')), add(x='xor.20589', y=add(x=add(x='add.20346', y='concat.32371'), y=add(x='add.16971', y='literal.23417'))), add(x='add.20346', y=add(x='xor.20589', y=add(x='concat.32371', y=add(x='add.16971', y='literal.23417')))), add(x=add(x='literal.23417', y=add(x='concat.32371', y='xor.20589')), y=add(x='add.20346', y='add.16971'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20541')
# [not_(x='add.20541')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20537',add('concat.32333','xor.20536'))
# [add(x='add.20537', y=add(x='concat.32333', y='xor.20536'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20280','add.20537')
# [add(x='add.20280', y='add.20537')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20281','concat.32295'),'xor.20524'),add('add.16922','literal.23410'))
# [add(x=add(x=add(x='add.20281', y='concat.32295'), y='xor.20524'), y=add(x='add.16922', y='literal.23410')), add(x='xor.20524', y=add(x=add(x='add.20281', y='concat.32295'), y=add(x='add.16922', y='literal.23410'))), add(x='add.20281', y=add(x='xor.20524', y=add(x='concat.32295', y=add(x='add.16922', y='literal.23410')))), add(x=add(x='literal.23410', y=add(x='concat.32295', y='xor.20524')), y=add(x='add.20281', y='add.16922'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20476')
# [not_(x='add.20476')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20472',add('concat.32257','xor.20471'))
# [add(x='add.20472', y=add(x='concat.32257', y='xor.20471'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20215','add.20472')
# [add(x='add.20215', y='add.20472')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20216','concat.32219'),'xor.20459'),add('add.16873','literal.23403'))
# [add(x=add(x=add(x='add.20216', y='concat.32219'), y='xor.20459'), y=add(x='add.16873', y='literal.23403')), add(x='xor.20459', y=add(x=add(x='add.20216', y='concat.32219'), y=add(x='add.16873', y='literal.23403'))), add(x='add.20216', y=add(x='xor.20459', y=add(x='concat.32219', y=add(x='add.16873', y='literal.23403')))), add(x=add(x='literal.23403', y=add(x='concat.32219', y='xor.20459')), y=add(x='add.20216', y='add.16873'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20411')
# [not_(x='add.20411')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20407',add('concat.32181','xor.20406'))
# [add(x='add.20407', y=add(x='concat.32181', y='xor.20406'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20150','add.20407')
# [add(x='add.20150', y='add.20407')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20151','concat.32143'),'xor.20394'),add('add.16824','literal.23396'))
# [add(x=add(x=add(x='add.20151', y='concat.32143'), y='xor.20394'), y=add(x='add.16824', y='literal.23396')), add(x='xor.20394', y=add(x=add(x='add.20151', y='concat.32143'), y=add(x='add.16824', y='literal.23396'))), add(x='add.20151', y=add(x='xor.20394', y=add(x='concat.32143', y=add(x='add.16824', y='literal.23396')))), add(x=add(x='literal.23396', y=add(x='concat.32143', y='xor.20394')), y=add(x='add.20151', y='add.16824'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20346')
# [not_(x='add.20346')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51449',add('concat.32105','xor.20341'))
# [add(x='add.51449', y=add(x='concat.32105', y='xor.20341'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20085','add.51449')
# [add(x='add.20085', y='add.51449')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.20086','concat.32067'),add('xor.20329','concat.51268'))
# [add(x=add(x='add.20086', y='concat.32067'), y=add(x='xor.20329', y='concat.51268')), add(x='concat.32067', y=add(x='add.20086', y=add(x='xor.20329', y='concat.51268')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20281')
# [not_(x='add.20281')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20277',add('concat.32029','xor.20276'))
# [add(x='add.20277', y=add(x='concat.32029', y='xor.20276'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20020','add.20277')
# [add(x='add.20020', y='add.20277')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20021','concat.31991'),'xor.20264'),add('add.16726','literal.23382'))
# [add(x=add(x=add(x='add.20021', y='concat.31991'), y='xor.20264'), y=add(x='add.16726', y='literal.23382')), add(x='xor.20264', y=add(x=add(x='add.20021', y='concat.31991'), y=add(x='add.16726', y='literal.23382'))), add(x='add.20021', y=add(x='xor.20264', y=add(x='concat.31991', y=add(x='add.16726', y='literal.23382')))), add(x=add(x='literal.23382', y=add(x='concat.31991', y='xor.20264')), y=add(x='add.20021', y='add.16726'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20216')
# [not_(x='add.20216')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51452',add('concat.31953','xor.20211'))
# [add(x='add.51452', y=add(x='concat.31953', y='xor.20211'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19955','add.51452')
# [add(x='add.19955', y='add.51452')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.19956','concat.31915'),add('xor.20199','concat.51263'))
# [add(x=add(x='add.19956', y='concat.31915'), y=add(x='xor.20199', y='concat.51263')), add(x='concat.31915', y=add(x='add.19956', y=add(x='xor.20199', y='concat.51263')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20151')
# [not_(x='add.20151')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51455',add('concat.31877','xor.20146'))
# [add(x='add.51455', y=add(x='concat.31877', y='xor.20146'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19890','add.51455')
# [add(x='add.19890', y='add.51455')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.19891','concat.31839'),add('xor.20134','concat.51258'))
# [add(x=add(x='add.19891', y='concat.31839'), y=add(x='xor.20134', y='concat.51258')), add(x='concat.31839', y=add(x='add.19891', y=add(x='xor.20134', y='concat.51258')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20086')
# [not_(x='add.20086')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51458',add('concat.31801','xor.20081'))
# [add(x='add.51458', y=add(x='concat.31801', y='xor.20081'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19825','add.51458')
# [add(x='add.19825', y='add.51458')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.19826','concat.31763'),add('xor.20069','concat.51253'))
# [add(x=add(x='add.19826', y='concat.31763'), y=add(x='xor.20069', y='concat.51253')), add(x='concat.31763', y=add(x='add.19826', y=add(x='xor.20069', y='concat.51253')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20021')
# [not_(x='add.20021')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51461',add('concat.31725','xor.20016'))
# [add(x='add.51461', y=add(x='concat.31725', y='xor.20016'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19760','add.51461')
# [add(x='add.19760', y='add.51461')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.19761','concat.31687'),add('xor.20004','concat.51248'))
# [add(x=add(x='add.19761', y='concat.31687'), y=add(x='xor.20004', y='concat.51248')), add(x='concat.31687', y=add(x='add.19761', y=add(x='xor.20004', y='concat.51248')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.19956')
# [not_(x='add.19956')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19952',add('concat.31649','xor.19951'))
# [add(x='add.19952', y=add(x='concat.31649', y='xor.19951'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19695','add.19952')
# [add(x='add.19695', y='add.19952')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.19696','concat.31611'),'xor.19939'),add('add.16481','literal.23347'))
# [add(x=add(x=add(x='add.19696', y='concat.31611'), y='xor.19939'), y=add(x='add.16481', y='literal.23347')), add(x='xor.19939', y=add(x=add(x='add.19696', y='concat.31611'), y=add(x='add.16481', y='literal.23347'))), add(x='add.19696', y=add(x='xor.19939', y=add(x='concat.31611', y=add(x='add.16481', y='literal.23347')))), add(x=add(x='literal.23347', y=add(x='concat.31611', y='xor.19939')), y=add(x='add.19696', y='add.16481'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.19891')
# [not_(x='add.19891')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51464',add('concat.31573','xor.19886'))
# [add(x='add.51464', y=add(x='concat.31573', y='xor.19886'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19630','add.51464')
# [add(x='add.19630', y='add.51464')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.19631','concat.31535'),add('xor.19874','concat.51243'))
# [add(x=add(x='add.19631', y='concat.31535'), y=add(x='xor.19874', y='concat.51243')), add(x='concat.31535', y=add(x='add.19631', y=add(x='xor.19874', y='concat.51243')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.19826')
# [not_(x='add.19826')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51467',add('concat.31497','xor.19821'))
# [add(x='add.51467', y=add(x='concat.31497', y='xor.19821'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19565','add.51467')
# [add(x='add.19565', y='add.51467')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.19566','concat.31459'),add('xor.19809','concat.51238'))
# [add(x=add(x='add.19566', y='concat.31459'), y=add(x='xor.19809', y='concat.51238')), add(x='concat.31459', y=add(x='add.19566', y=add(x='xor.19809', y='concat.51238')))]
# FunctionName:  __sha256__main
# Input Expr:  add('concat.51560','literal.51398')
# [add(x='concat.51560', y='literal.51398')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51339','literal.51397')
# [add(x='bit_slice.51339', y='literal.51397')]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.19761')
# [not_(x='add.19761')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51470',add('concat.31421','xor.19756'))
# [add(x='add.51470', y=add(x='concat.31421', y='xor.19756'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19500','add.51470')
# [add(x='add.19500', y='add.51470')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.17706','concat.29988'),add('add.18147','concat.30005'))
# [add(x=add(x='add.17706', y='concat.29988'), y=add(x='add.18147', y='concat.30005')), add(x='concat.29988', y=add(x='add.17706', y=add(x='add.18147', y='concat.30005')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.17657','concat.29926'),add('add.18098','concat.29943'))
# [add(x=add(x='add.17657', y='concat.29926'), y=add(x='add.18098', y='concat.29943')), add(x='concat.29926', y=add(x='add.17657', y=add(x='add.18098', y='concat.29943')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.19501','concat.31383'),add('xor.19744','concat.51233'))
# [add(x=add(x='add.19501', y='concat.31383'), y=add(x='xor.19744', y='concat.51233')), add(x='concat.31383', y=add(x='add.19501', y=add(x='xor.19744', y='concat.51233')))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51334','literal.51396')
# [add(x='bit_slice.51334', y='literal.51396')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51329','literal.51395')
# [add(x='bit_slice.51329', y='literal.51395')]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.19696')
# [not_(x='add.19696')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.17608','concat.29864'),add('add.18049','concat.29881'))
# [add(x=add(x='add.17608', y='concat.29864'), y=add(x='add.18049', y='concat.29881')), add(x='concat.29864', y=add(x='add.17608', y=add(x='add.18049', y='concat.29881')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.17559','concat.29802'),add('add.18000','concat.29819'))
# [add(x=add(x='add.17559', y='concat.29802'), y=add(x='add.18000', y='concat.29819')), add(x='concat.29802', y=add(x='add.17559', y=add(x='add.18000', y='concat.29819')))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19692',add('concat.31345','xor.19691'))
# [add(x='add.19692', y=add(x='concat.31345', y='xor.19691'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19435','add.19692')
# [add(x='add.19435', y='add.19692')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add
))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51314','literal.51392')
# [add(x='bit_slice.51314', y='literal.51392')]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.19501')
# [not_(x='add.19501')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.17216','concat.29368'),add('add.17657','concat.29385'))
# [add(x=add(x='add.17216', y='concat.29368'), y=add(x='add.17657', y='concat.29385')), add(x='concat.29368', y=add(x='add.17216', y=add(x='add.17657', y='concat.29385')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.17167','concat.29306'),add('add.17608','concat.29323'))
# [add(x=add(x='add.17167', y='concat.29306'), y=add(x='add.17608', y='concat.29323')), add(x='concat.29306', y=add(x='add.17167', y=add(x='add.17608', y='concat.29323')))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51476',add('concat.31117','xor.19496'))
# [add(x='add.51476', y=add(x='concat.31117', y='xor.19496'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19240','add.51476')
# [add(x='add.19240', y='add.51476')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.19241','concat.31079'),add('xor.19484','concat.51223'))
# [add(x=add(x='add.19241', y='concat.31079'), y=add(x='xor.19484', y='concat.51223')), add(x='concat.31079', y=add(x='add.19241', y=add(x='xor.19484', y='concat.51223')))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51309','literal.51391')
# [add(x='bit_slice.51309', y='literal.51391')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51304','literal.51390')
# [add(x='bit_slice.51304', y='literal.51390')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.17118','concat.29244'),add('add.17559','concat.29261'))
# [add(x=add(x='add.17118', y='concat.29244'), y=add(x='add.17559', y='concat.29261')), add(x='concat.29244', y=add(x='add.17118', y=add(x='add.17559', y='concat.29261')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.17069','concat.29182'),add('add.17510','concat.29199'))
# [add(x=add(x='add.17069', y='concat.29182'), y=add(x='add.17510', y='concat.29199')), add(x='concat.29182', y=add(x='add.17069', y=add(x='add.17510', y='concat.29199')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.19436')
# [not_(x='add.19436')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51479',add('concat.31041','xor.19431'))
# [add(x='add.51479', y=add(x='concat.31041', y='xor.19431'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19175','add.51479')
# [add(x='add.19175', y='add.51479')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.19176','concat.31003'),add('xor.19419','concat.51218'))
# [add(x=add(x='add.19176', y='concat.31003'), y=add(x='xor.19419', y='concat.51218')), add(x='concat.31003', y=add(x='add.19176', y=add(x='xor.19419', y='concat.51218')))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51299','literal.51389')
# [add(x='bit_slice.51299', y='literal.51389')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.17020','concat.29120'),add('add.17461','concat.29137'))
# [add(x=add(x='add.17020', y='concat.29120'), y=add(x='add.17461', y='concat.29137')), add(x='concat.29120', y=add(x='add.17020', y=add(x='add.17461', y='concat.29137')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.16971','concat.29058'),add('add.17412','concat.29075'))
# ...
# FunctionName:  __sha256__main
# Input Expr:  not_('add.19176')
# [not_(x='add.19176')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51485',add('concat.30737','xor.19171'))
# [add(x='add.51485', y=add(x='concat.30737', y='xor.19171'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.18915','add.51485')
# [add(x='add.18915', y='add.51485')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51279','literal.51385')
# [add(x='bit_slice.51279', y='literal.51385')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.18916','concat.30699'),add('xor.19159','concat.51208'))
# [add(x=add(x='add.18916', y='concat.30699'), y=add(x='xor.19159', y='concat.51208')), add(x='concat.30699', y=add(x='add.18916', y=add(x='xor.19159', y='concat.51208')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.16530','concat.28500'),add('add.16971','concat.28517'))
# [add(x=add(x='add.16530', y='concat.28500'), y=add(x='add.16971', y='concat.28517')), add(x='concat.28500', y=add(x='add.16530', y=add(x='add.16971', y='concat.28517')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.
]
# FunctionName:  __sha256__main
# Input Expr:  add(add('concat.30319','xor.18834'),'concat.51198')
# [add(x=add(x='concat.30319', y='xor.18834'), y='concat.51198'), add(x='xor.18834', y=add(x='concat.30319', y='concat.51198'))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51254','literal.51380')
# [add(x='bit_slice.51254', y='literal.51380')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51249','literal.51379')
# [add(x='bit_slice.51249', y='literal.51379')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('bit_slice.16228','concat.27632'),add('add.16285','concat.27649'))
# [add(x=add(x='bit_slice.16228', y='concat.27632'), y=add(x='add.16285', y='concat.27649')), add(x='concat.27632', y=add(x='bit_slice.16228', y=add(x='add.16285', y='concat.27649')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('bit_slice.16227','concat.27570'),add('bit_slice.16236','concat.27587'))
# [add(x=add(x='bit_slice.16227', y='concat.27570'), y=add(x='bit_slice.16236', y='concat.27587')), add(x='concat.27570', y=add(x='bit_slice.16227', y=add(x='bit_slice.16236', y='concat.27587')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.37936')
# [not_(x='add.37936')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.37949',add('concat.30281','xor.18781'))
# [add(x='add.37949', y=add(x='concat.30281', y='xor.18781'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.37949','literal.51596')
# [add(x='add.37949', y='literal.51596')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('concat.30243','xor.18769'),add('bit_slice.16223','literal.37955'))
# [add(x=add(x='concat.30243', y='xor.18769'), y=add(x='bit_slice.16223', y='literal.37955')), add(x='xor.18769', y=add(x='concat.30243', y=add(x='bit_slice.16223', y='literal.37955')))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51244','literal.51378')
# [add(x='bit_slice.51244', y='literal.51378')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('bit_slice.16226','concat.27508'),add('bit_slice.16235','concat.27525'))
# [add(x=add(x='bit_slice.16226', y='concat.27508'), y=add(x='bit_slice.16235', y='concat.27525')), add(x='concat.27508', y=add(x='bit_slice.16226', y=add(x='bit_slice.16235', y='concat.27525')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('bit_slice.16225','concat.27446'),add('bit_slice.16234','concat.27463'))
# [add(x=add(x='bit_slice.16225', y='concat.27446'), y=add(x='bit_slice.16234', y='concat.27463')), add(x='concat.27446', y=add(x='bit_slice.16225', y=add(x='bit_slice.16234', y='concat.27463')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.51191')
# [not_(x='add.51191')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51239','literal.51377')
# [add(x='bit_slice.51239', y='literal.51377')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51234','literal.51376')
# [add(x='bit_slice.51234', y='literal.51376')]
# FunctionName:  __sha256__main
# Input Expr:  not_('bit_slice.51192')
# [not_(x='bit_slice.51192')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51189','literal.51367')
# [add(x='bit_slice.51189', y='literal.51367')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.37953',add('concat.30205','xor.18716'))
# [add(x='add.37953', y=add(x='concat.30205', y='xor.18716'))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('bit_slice.16224','concat.27384'),add('bit_slice.16233','concat.27401'))
# [add(x=add(x='bit_slice.16224', y='concat.27384'), y=add(x='bit_slice.16233', y='concat.27401')), add(x='concat.27384', y=add(x='bit_slice.16224', y=add(x='bit_slice.16233', y='concat.27401')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('bit_slice.16223','concat.27322'),add('bit_slice.16232','concat.27339'))
# [add(x=add(x='bit_slice.16223', y='concat.27322'), y=add(x='bit_slice.16232', y='concat.27339')), add(x='concat.27322', y=add(x='bit_slice.16223', y=add(x='bit_slice.16232', y='concat.27339')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('concat.30167','xor.18704'),'concat.51188')
# [add(x=add(x='concat.30167', y='xor.18704'), y='concat.51188'), add(x='xor.18704', y=add(x='concat.30167', y='concat.51188'))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51229','literal.51375')
# [add(x='bit_slice.51229', y='literal.51375')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('bit_slice.16222','concat.27260'),add('bit_slice.16231','concat.27277'))
# [add(x=add(x='bit_slice.16222', y='concat.27260'), y=add(x='bit_slice.16231', y='concat.27277')), add(x='concat.27260', y=add(x='bit_slice.16222', y=add(x='bit_slice.16231', y='concat.27277')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('bit_slice.16221','concat.27198'),add('bit_slice.16230','concat.27215'))
# [add(x=add(x='bit_slice.16221', y='concat.27198'), y=add(x='bit_slice.16230', y='concat.27215')), add(x='concat.27198', y=add(x='bit_slice.16221', y=add(x='bit_slice.16230', y='concat.27215')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.51181')
# [not_(x='add.51181')]
# FunctionName:  __sha256__main
# Input Expr:  add('concat.51178','literal.23206')
# [add(x='concat.51178', y='literal.23206')]
# FunctionName:  __sha256__main
# Input Expr:  add('concat.51540','literal.51365')
# [add(x='concat.51540', y='literal.51365')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51557','literal.51374')
# [add(x='bit_slice.51557', y='literal.51374')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51555','literal.51373')
# [add(x='bit_slice.51555', y='literal.51373')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51553','literal.51372')
# [add(x='bit_slice.51553', y='literal.51372')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51551','literal.51371')
# [add(x='bit_slice.51551', y='literal.51371')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51549','literal.51370')
# [add(x='bit_slice.51549', y='literal.51370')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51547','literal.51369')
# [add(x='bit_slice.51547', y='literal.51369')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51545','literal.51368')
# [add(x='bit_slice.51545', y='literal.51368')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51543','literal.51366')
# [add(x='bit_slice.51543', y='literal.51366')]
# FunctionName:  __sha256__main
# Input Expr:  not_('bit_slice.51564')
# [not_(x='bit_slice.51564')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51537','literal.51364')
# [add(x='bit_slice.51537', y='literal.51364')]
#
# Running Standalone Rewriter
# Rewriter Run Done
# Scheduling Run Done.
# Reading Scheduling Result
# Result Graph Generation Done
# Number Of Nodes After:  4929 Reg count:  1235
# Max Pipeline Latency After:  3960 stages: 56

# %%
# The subsequent parts are for generating graphs for each rewrite expressions,
# as well as testing ways to use these graphs

# %%
# These are helper functions for selectors
def expr_to_graph(G, expr, bit_width, cur_operation_mapping):
    cur_graph = nx.DiGraph()
    nodes_involved_dict, out_node_name = gen_json_from_expr_recursive(G, str(expr), cur_operation_mapping, bit_width)
    filtered_dict = {k: v for k, v in nodes_involved_dict.items() if v['ReplaceSelfWith'] == 'Gen'}
    node_obj_dict = dict_to_nodes(filtered_dict)
#     print(node_obj_dict, "\n")
    node_name_list = list(node_obj_dict.keys())
    new_nodes = {}
    # Iterate over the nodes and check for missing operands
    for node_name, node_obj in node_obj_dict.items():
        if node_obj.operands != None:
            for operand in node_obj.operands:
                if operand not in node_name_list and operand not in new_nodes:
                    # Create a new Node object for the missing operand
                    new_nodes[operand] = Node(name=operand, operands=[])
        else:
            node_obj.operands = []
        
    # Merge the new nodes into the main dictionary
    node_obj_dict.update(new_nodes)
    counter = 0
    for node_name, node_obj in node_obj_dict.items():
        node_obj.idNum = counter
        counter += 1
    cur_graph = DictToGraph(cur_graph, node_obj_dict)
#     print("expr: ", expr)
#     print("graph", cur_graph.nodes(), "\n")
    return cur_graph

def dict_to_nodes(node_dict):
    inversed_mapping = {"kAdd" : "add",
                          "kUMul" : "mul",
                        "kSMul" : "mul",
                          "kUDiv" : "div",
                        "kSDiv" : "div",
                          "kSub" : "sub",
                        "Literal" : "literal",
                         "kNeg" : "neg",
                         "kShll" : "shll",
                         "kShrl" : "shrl",
                         "kNot" : "not_",
                       "kConcat" : "concat",
                       "bit_slice" : "bitslice"}
    node_objects = {}    
    for node_name, node_data in node_dict.items():
        if node_data.get("OperationType") in inversed_mapping.keys():
            mapped_operation = inversed_mapping[node_data.get("OperationType")]
        else:
            mapped_operation = node_data.get("OperationType")
        # Create Node object using the data from the dictionary
        node = Node(
            name=node_data.get("OperationName"),
            bitwidth=node_data.get("BitWidth"),
            operation=mapped_operation,
            operands=node_data.get("Operands"),
            idNum=node_data.get("idNum"),
            value=node_data.get("Value"),
            pos=node_data.get("Pos"),
            FuncIO=node_data.get("FuncIO"),
            start=node_data.get("Start"),
            width=node_data.get("Width"),
            array_sizes=node_data.get("ArraySize"),
            indices=node_data.get("Indices")
        )
        # Store the Node object using the node name as the key
        node_objects[node_name] = node
    return node_objects

# %%
def get_graph_with_smallest_longest_path(graph_list):
    min_longest_path_length = float('inf')
    index_of_min = -1

    for i, graph in enumerate(graph_list):
        try:
            # Assuming the graph is a DAG
            longest_path_length = len(nx.dag_longest_path(graph)) - 1  # Subtract 1 to get the number of edges
            if longest_path_length < min_longest_path_length:
                min_longest_path_length = longest_path_length
                index_of_min = i
            elif longest_path_length == min_longest_path_length:
                # Update the index if it's larger in case of tie
                index_of_min = max(index_of_min, i)
        except nx.NetworkXUnfeasible:
            # This exception is raised if the graph is not a DAG
            print(f"Graph at index {i} is not a DAG.")

    return index_of_min

def get_graph_with_fewest_nodes(graph_list):
    min_node_count = float('inf')
    index_of_min = -1

    for i, graph in enumerate(graph_list):
        node_count = len(graph.nodes)

        if node_count < min_node_count:
            min_node_count = node_count
            index_of_min = i
        elif node_count == min_node_count:
            # Update the index if it's larger in case of tie
            index_of_min = max(index_of_min, i)
#         print(node_count)
#     print("Chose: ", index_of_min)
    return index_of_min


def naive_pick(G, cur_rewrite_candidate, bit_width, cur_operation_mapping):
    graph_list = []
    for cur_expr in cur_rewrite_candidate:
        cur_graph = expr_to_graph(G, cur_expr,  bit_width, cur_operation_mapping)
        graph_list.append(cur_graph)  
#         print(cur_expr)
#         print(cur_graph.nodes)

#     native_pick_index = get_graph_with_smallest_longest_path(graph_list)
    native_pick_index = get_graph_with_fewest_nodes(graph_list)
    best_rewrite = cur_rewrite_candidate[native_pick_index]
#     print(native_pick_index)
#     print("\n")
    return best_rewrite

# %%
G, FuncName = gen_json_from_ir("/home/miao/xls/work_space/Sha256/sha256.opt.ir", "/home/miao/xls/work_space/Sha256/sha256.json", rewrite_rule="NativePick")
# nx.draw(G, with_labels=True, font_weight='bold')
# G, FuncName = gen_json_from_ir("/home/miao/xls/work_space/EGraphUnitTest/all_unit_test.ir", "/home/miao/xls/work_space/EGraphUnitTest/all_unit_test.json", rewrite_rule="NativePick")
# Out:
# FunctionName:  __sha256__main
# Input Expr:  add(add('a__60','temp1__345'),'f__66')
# [add(x=add(x='a__60', y='temp1__345'), y='f__66'), add(x='temp1__345', y=add(x='a__60', y='f__66'))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('temp1__345','S0__63'),add('maj__63','b__68'))
# [add(x=add(x='temp1__345', y='S0__63'), y=add(x='maj__63', y='b__68')), add(x='S0__63', y=add(x='temp1__345', y=add(x='maj__63', y='b__68')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__60','S1__63'),add('ch__63','value__96')),add(add('s_0__47','value__123'),'temp1__342'))
# [add(x=add(x=add(x='e__60', y='S1__63'), y=add(x='ch__63', y='value__96')), y=add(x=add(x='s_0__47', y='value__123'), y='temp1__342')), add(x=add(x='ch__63', y='value__96'), y=add(x=add(x='e__60', y='S1__63'), y=add(x=add(x='s_0__47', y='value__123'), y='temp1__342'))), add(x=add(x=add(x='e__60', y='S1__63'), y='value__96'), y=add(x='ch__63', y=add(x='s_0__47', y=add(x='value__123', y='temp1__342')))), add(x='S1__63', y=add(x=add(x=add(x='s_0__47', y='value__123'), y='temp1__342'), y=add(x='ch__63', y=add(x='e__60', y='value__96')))), add(x=add(x='S1__63', y=add(x='temp1__342', y=add(x='e__60', y='value__123'))), y=add(x=add(x='value__96', y='s_0__47'), y='ch__63')), add(x='e__60', y=add(x='S1__63', y=add(x=add(x='ch__63', y='value__96'), y=add(x=add(x='s_0__47', y='value__123'), y='temp1__342')))), add(x='S1__63', y=add(x=add(x='value__96', y='s_0__47'), y=add(x='e__60', y=add(x='temp1__342', y=add(x='ch__63', y='value__123')))))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51359','literal.51401')
# [add(x='bit_slice.51359', y='literal.51401')]
# FunctionName:  __sha256__main
# Input Expr:  add('a__63','c__66')
# [add(x='a__63', y='c__66')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__352',add('S0__62','maj__62'))
# [add(x='temp1__352', y=add(x='S0__62', y='maj__62'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__59','temp1__352')
# [add(x='a__59', y='temp1__352')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__59','S1__62'),add('ch__62','value__93')),add(add('s_0__46','value__120'),add('s_1__46','literal.23641')))
# [add(x=add(x=add(x='e__59', y='S1__62'), y=add(x='ch__62', y='value__93')), y=add(x=add(x='s_0__46', y='value__120'), y=add(x='s_1__46', y='literal.23641'))), add(x=add(x='ch__62', y='value__93'), y=add(x=add(x='e__59', y='S1__62'), y=add(x='value__120', y=add(x='s_0__46', y=add(x='s_1__46', y='literal.23641'))))), add(x='e__59', y=add(x=add(x='ch__62', y='value__93'), y=add(x='S1__62', y=add(x=add(x='s_0__46', y='value__120'), y=add(x='s_1__46', y='literal.23641'))))), add(x='S1__62', y=add(x='e__59', y=add(x=add(x='s_0__46', y='value__120'), y=add(x=add(x='ch__62', y='value__93'), y=add(x='s_1__46', y='literal.23641'))))), add(x='S1__62', y=add(x=add(x=add(x='s_0__46', y=add(x='e__59', y='value__120')), y=add(x='value__93', y=add(x='s_1__46', y='literal.23641'))), y='ch__62')), add(x='e__59', y=add(x='value__93', y=add(x='S1__62', y=add(x='s_0__46', y=add(x='ch__62', y=add(x='value__120', y=add(x='s_1__46', y='literal.23641'))))))), add(x='e__59', y=add(x='value__120', y=add(x=add(x='S1__62', y='s_0__46'), y=add(x='ch__62', y=add(x='value__93', y=add(x='s_1__46', y='literal.23641'))))))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51349','literal.51598')
# [add(x='bit_slice.51349', y='literal.51598')]
# FunctionName:  __sha256__main
# Input Expr:  add('e__62','h__1')
# [add(x='e__62', y='h__1')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__248',add('S0__61','maj__61'))
# [add(x='temp1__248', y=add(x='S0__61', y='maj__61'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__58','temp1__248')
# [add(x='a__58', y='temp1__248')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__58','S1__61'),'ch__61'),add('value__138','literal.23634'))
# [add(x=add(x=add(x='e__58', y='S1__61'), y='ch__61'), y=add(x='value__138', y='literal.23634')), add(x='ch__61', y=add(x=add(x='e__58', y='S1__61'), y=add(x='value__138', y='literal.23634'))), add(x='e__58', y=add(x='ch__61', y=add(x='S1__61', y=add(x='value__138', y='literal.23634')))), add(x=add(x='literal.23634', y=add(x='S1__61', y='ch__61')), y=add(x='e__58', y='value__138'))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51354','literal.51597')
# [add(x='bit_slice.51354', y='literal.51597')]
# FunctionName:  __sha256__main
# Input Expr:  add('e__61','h7')
# [add(x='e__61', y='h7')]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__61')
# [not_(x='e__61')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__355',add('S0__60','maj__60'))
# [add(x='temp1__355', y=add(x='S0__60', y='maj__60'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__57','temp1__355')
# [add(x='a__57', y='temp1__355')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__57','S1__60'),add('ch__60','temp1__318'))
# [add(x=add(x='e__57', y='S1__60'), y=add(x='ch__60', y='temp1__318')), add(x='S1__60', y=add(x='e__57', y=add(x='ch__60', y='temp1__318')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__60')
# [not_(x='e__60')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__358',add('S0__59','maj__59'))
# [add(x='temp1__358', y=add(x='S0__59', y='maj__59'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__56','temp1__358')
# [add(x='a__56', y='temp1__358')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__56','S1__59'),add('ch__59','temp1__317'))
# [add(x=add(x='e__56', y='S1__59'), y=add(x='ch__59', y='temp1__317')), add(x='S1__59', y=add(x='e__56', y=add(x='ch__59', y='temp1__317')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__59')
# [not_(x='e__59')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__361',add('S0__58','maj__58'))
# [add(x='temp1__361', y=add(x='S0__58', y='maj__58'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__55','temp1__361')
# [add(x='a__55', y='temp1__361')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__55','S1__58'),add('ch__58','temp1__316'))
# [add(x=add(x='e__55', y='S1__58'), y=add(x='ch__58', y='temp1__316')), add(x='S1__58', y=add(x='e__55', y=add(x='ch__58', y='temp1__316')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__58')
# [not_(x='e__58')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__232',add('S0__57','maj__57'))
# [add(x='temp1__232', y=add(x='S0__57', y='maj__57'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__54','temp1__232')
# [add(x='a__54', y='temp1__232')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__54','S1__57'),'ch__57'),add('value__126','literal.23606'))
# [add(x=add(x=add(x='e__54', y='S1__57'), y='ch__57'), y=add(x='value__126', y='literal.23606')), add(x='ch__57', y=add(x=add(x='e__54', y='S1__57'), y=add(x='value__126', y='literal.23606'))), add(x='e__54', y=add(x='ch__57', y=add(x='S1__57', y=add(x='value__126', y='literal.23606')))), add(x=add(x='literal.23606', y=add(x='S1__57', y='ch__57')), y=add(x='e__54', y='value__126'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__57')
# [not_(x='e__57')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__364',add('S0__56','maj__56'))
# [add(x='temp1__364', y=add(x='S0__56', y='maj__56'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__53','temp1__364')
# [add(x='a__53', y='temp1__364')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__53','S1__56'),add('ch__56','temp1__314'))
# [add(x=add(x='e__53', y='S1__56'), y=add(x='ch__56', y='temp1__314')), add(x='S1__56', y=add(x='e__53', y=add(x='ch__56', y='temp1__314')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__56')
# [not_(x='e__56')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__224',add('S0__55','maj__55'))
# [add(x='temp1__224', y=add(x='S0__55', y='maj__55'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__52','temp1__224')
# [add(x='a__52', y='temp1__224')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__52','S1__55'),'ch__55'),add('value__120','literal.23592'))
# [add(x=add(x=add(x='e__52', y='S1__55'), y='ch__55'), y=add(x='value__120', y='literal.23592')), add(x='ch__55', y=add(x=add(x='e__52', y='S1__55'), y=add(x='value__120', y='literal.23592'))), add(x='e__52', y=add(x='ch__55', y=add(x='S1__55', y=add(x='value__120', y='literal.23592')))), add(x=add(x='literal.23592', y=add(x='S1__55', y='ch__55')), y=add(x='e__52', y='value__120'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__55')
# [not_(x='e__55')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__220',add('S0__54','maj__54'))
# [add(x='temp1__220', y=add(x='S0__54', y='maj__54'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__51','temp1__220')
# [add(x='a__51', y='temp1__220')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__51','S1__54'),'ch__54'),add('value__117','literal.23585'))
# [add(x=add(x=add(x='e__51', y='S1__54'), y='ch__54'), y=add(x='value__117', y='literal.23585')), add(x='ch__54', y=add(x=add(x='e__51', y='S1__54'), y=add(x='value__117', y='literal.23585'))), add(x='e__51', y=add(x='ch__54', y=add(x='S1__54', y=add(x='value__117', y='literal.23585')))), add(x=add(x='literal.23585', y=add(x='S1__54', y='ch__54')), y=add(x='e__51', y='value__117'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__54')
# [not_(x='e__54')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__367',add('S0__53','maj__53'))
# [add(x='temp1__367', y=add(x='S0__53', y='maj__53'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__50','temp1__367')
# [add(x='a__50', y='temp1__367')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__50','S1__53'),add('ch__53','temp1__311'))
# [add(x=add(x='e__50', y='S1__53'), y=add(x='ch__53', y='temp1__311')), add(x='S1__53', y=add(x='e__50', y=add(x='ch__53', y='temp1__311')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__53')
# [not_(x='e__53')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__212',add('S0__52','maj__52'))
# [add(x='temp1__212', y=add(x='S0__52', y='maj__52'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__49','temp1__212')
# [add(x='a__49', y='temp1__212')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__49','S1__52'),'ch__52'),add('value__111','literal.23571'))
# [add(x=add(x=add(x='e__49', y='S1__52'), y='ch__52'), y=add(x='value__111', y='literal.23571')), add(x='ch__52', y=add(x=add(x='e__49', y='S1__52'), y=add(x='value__111', y='literal.23571'))), add(x='e__49', y=add(x='ch__52', y=add(x='S1__52', y=add(x='value__111', y='literal.23571')))), add(x=add(x='literal.23571', y=add(x='S1__52', y='ch__52')), y=add(x='e__49', y='value__111'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__52')
# [not_(x='e__52')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__208',add('S0__51','maj__51'))
# [add(x='temp1__208', y=add(x='S0__51', y='maj__51'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__48','temp1__208')
# [add(x='a__48', y='temp1__208')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__48','S1__51'),'ch__51'),add('value__108','literal.23564'))
# [add(x=add(x=add(x='e__48', y='S1__51'), y='ch__51'), y=add(x='value__108', y='literal.23564')), add(x='ch__51', y=add(x=add(x='e__48', y='S1__51'), y=add(x='value__108', y='literal.23564'))), add(x='e__48', y=add(x='ch__51', y=add(x='S1__51', y=add(x='value__108', y='literal.23564')))), add(x=add(x='literal.23564', y=add(x='S1__51', y='ch__51')), y=add(x='e__48', y='value__108'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__51')
# [not_(x='e__51')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__370',add('S0__50','maj__50'))
# [add(x='temp1__370', y=add(x='S0__50', y='maj__50'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__47','temp1__370')
# [add(x='a__47', y='temp1__370')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__47','S1__50'),add('ch__50','temp1__308'))
# [add(x=add(x='e__47', y='S1__50'), y=add(x='ch__50', y='temp1__308')), add(x='S1__50', y=add(x='e__47', y=add(x='ch__50', y='temp1__308')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__50')
# [not_(x='e__50')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__373',add('S0__49','maj__49'))
# [add(x='temp1__373', y=add(x='S0__49', y='maj__49'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__46','temp1__373')
# [add(x='a__46', y='temp1__373')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__46','S1__49'),add('ch__49','temp1__307'))
# [add(x=add(x='e__46', y='S1__49'), y=add(x='ch__49', y='temp1__307')), add(x='S1__49', y=add(x='e__46', y=add(x='ch__49', y='temp1__307')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__49')
# [not_(x='e__49')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__376',add('S0__48','maj__48'))
# [add(x='temp1__376', y=add(x='S0__48', y='maj__48'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__45','temp1__376')
# [add(x='a__45', y='temp1__376')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__45','S1__48'),add('ch__48','temp1__306'))
# [add(x=add(x='e__45', y='S1__48'), y=add(x='ch__48', y='temp1__306')), add(x='S1__48', y=add(x='e__45', y=add(x='ch__48', y='temp1__306')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__48')
# [not_(x='e__48')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__379',add('S0__47','maj__47'))
# [add(x='temp1__379', y=add(x='S0__47', y='maj__47'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__44','temp1__379')
# [add(x='a__44', y='temp1__379')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__44','S1__47'),add('ch__47','temp1__305'))
# [add(x=add(x='e__44', y='S1__47'), y=add(x='ch__47', y='temp1__305')), add(x='S1__47', y=add(x='e__44', y=add(x='ch__47', y='temp1__305')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__47')
# [not_(x='e__47')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__188',add('S0__46','maj__46'))
# [add(x='temp1__188', y=add(x='S0__46', y='maj__46'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__43','temp1__188')
# [add(x='a__43', y='temp1__188')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__43','S1__46'),'ch__46'),add('value__93','literal.23529'))
# [add(x=add(x=add(x='e__43', y='S1__46'), y='ch__46'), y=add(x='value__93', y='literal.23529')), add(x='ch__46', y=add(x=add(x='e__43', y='S1__46'), y=add(x='value__93', y='literal.23529'))), add(x='e__43', y=add(x='ch__46', y=add(x='S1__46', y=add(x='value__93', y='literal.23529')))), add(x=add(x='literal.23529', y=add(x='S1__46', y='ch__46')), y=add(x='e__43', y='value__93'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__46')
# [not_(x='e__46')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__382',add('S0__45','maj__45'))
# [add(x='temp1__382', y=add(x='S0__45', y='maj__45'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__42','temp1__382')
# [add(x='a__42', y='temp1__382')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__42','S1__45'),add('ch__45','temp1__303'))
# [add(x=add(x='e__42', y='S1__45'), y=add(x='ch__45', y='temp1__303')), add(x='S1__45', y=add(x='e__42', y=add(x='ch__45', y='temp1__303')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__45')
# [not_(x='e__45')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__180',add('S0__44','maj__44'))
# [add(x='temp1__180', y=add(x='S0__44', y='maj__44'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__41','temp1__180')
# [add(x='a__41', y='temp1__180')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__41','S1__44'),'ch__44'),add('value__87','literal.23515'))
# [add(x=add(x=add(x='e__41', y='S1__44'), y='ch__44'), y=add(x='value__87', y='literal.23515')), add(x='ch__44', y=add(x=add(x='e__41', y='S1__44'), y=add(x='value__87', y='literal.23515'))), add(x='e__41', y=add(x='ch__44', y=add(x='S1__44', y=add(x='value__87', y='literal.23515')))), add(x=add(x='literal.23515', y=add(x='S1__44', y='ch__44')), y=add(x='e__41', y='value__87'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__44')
# [not_(x='e__44')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__176',add('S0__43','maj__43'))
# [add(x='temp1__176', y=add(x='S0__43', y='maj__43'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__40','temp1__176')
# [add(x='a__40', y='temp1__176')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__40','S1__43'),'ch__43'),add('value__84','literal.23508'))
# [add(x=add(x=add(x='e__40', y='S1__43'), y='ch__43'), y=add(x='value__84', y='literal.23508')), add(x='ch__43', y=add(x=add(x='e__40', y='S1__43'), y=add(x='value__84', y='literal.23508'))), add(x='e__40', y=add(x='ch__43', y=add(x='S1__43', y=add(x='value__84', y='literal.23508')))), add(x=add(x='literal.23508', y=add(x='S1__43', y='ch__43')), y=add(x='e__40', y='value__84'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__43')
# [not_(x='e__43')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__385',add('S0__42','maj__42'))
# [add(x='temp1__385', y=add(x='S0__42', y='maj__42'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__39','temp1__385')
# [add(x='a__39', y='temp1__385')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__39','S1__42'),add('ch__42','temp1__300'))
# [add(x=add(x='e__39', y='S1__42'), y=add(x='ch__42', y='temp1__300')), add(x='S1__42', y=add(x='e__39', y=add(x='ch__42', y='temp1__300')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__42')
# [not_(x='e__42')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__168',add('S0__41','maj__41'))
# [add(x='temp1__168', y=add(x='S0__41', y='maj__41'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__38','temp1__168')
# [add(x='a__38', y='temp1__168')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__38','S1__41'),'ch__41'),add('value__78','literal.23494'))
# [add(x=add(x=add(x='e__38', y='S1__41'), y='ch__41'), y=add(x='value__78', y='literal.23494')), add(x='ch__41', y=add(x=add(x='e__38', y='S1__41'), y=add(x='value__78', y='literal.23494'))), add(x='e__38', y=add(x='ch__41', y=add(x='S1__41', y=add(x='value__78', y='literal.23494')))), add(x=add(x='literal.23494', y=add(x='S1__41', y='ch__41')), y=add(x='e__38', y='value__78'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__41')
# [not_(x='e__41')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__164',add('S0__40','maj__40'))
# [add(x='temp1__164', y=add(x='S0__40', y='maj__40'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__37','temp1__164')
# [add(x='a__37', y='temp1__164')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__37','S1__40'),'ch__40'),add('value__75','literal.23487'))
# [add(x=add(x=add(x='e__37', y='S1__40'), y='ch__40'), y=add(x='value__75', y='literal.23487')), add(x='ch__40', y=add(x=add(x='e__37', y='S1__40'), y=add(x='value__75', y='literal.23487'))), add(x='e__37', y=add(x='ch__40', y=add(x='S1__40', y=add(x='value__75', y='literal.23487')))), add(x=add(x='literal.23487', y=add(x='S1__40', y='ch__40')), y=add(x='e__37', y='value__75'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__40')
# [not_(x='e__40')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__160',add('S0__39','maj__39'))
# [add(x='temp1__160', y=add(x='S0__39', y='maj__39'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__36','temp1__160')
# [add(x='a__36', y='temp1__160')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__36','S1__39'),'ch__39'),add('value__72','literal.23480'))
# [add(x=add(x=add(x='e__36', y='S1__39'), y='ch__39'), y=add(x='value__72', y='literal.23480')), add(x='ch__39', y=add(x=add(x='e__36', y='S1__39'), y=add(x='value__72', y='literal.23480'))), add(x='e__36', y=add(x='ch__39', y=add(x='S1__39', y=add(x='value__72', y='literal.23480')))), add(x=add(x='literal.23480', y=add(x='S1__39', y='ch__39')), y=add(x='e__36', y='value__72'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__39')
# [not_(x='e__39')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__388',add('S0__38','maj__38'))
# [add(x='temp1__388', y=add(x='S0__38', y='maj__38'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__35','temp1__388')
# [add(x='a__35', y='temp1__388')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__35','S1__38'),add('ch__38','temp1__296'))
# [add(x=add(x='e__35', y='S1__38'), y=add(x='ch__38', y='temp1__296')), add(x='S1__38', y=add(x='e__35', y=add(x='ch__38', y='temp1__296')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__38')
# [not_(x='e__38')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__152',add('S0__37','maj__37'))
# [add(x='temp1__152', y=add(x='S0__37', y='maj__37'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__34','temp1__152')
# [add(x='a__34', y='temp1__152')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__34','S1__37'),'ch__37'),add('value__66','literal.23466'))
# [add(x=add(x=add(x='e__34', y='S1__37'), y='ch__37'), y=add(x='value__66', y='literal.23466')), add(x='ch__37', y=add(x=add(x='e__34', y='S1__37'), y=add(x='value__66', y='literal.23466'))), add(x='e__34', y=add(x='ch__37', y=add(x='S1__37', y=add(x='value__66', y='literal.23466')))), add(x=add(x='literal.23466', y=add(x='S1__37', y='ch__37')), y=add(x='e__34', y='value__66'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__37')
# [not_(x='e__37')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__391',add('S0__36','maj__36'))
# [add(x='temp1__391', y=add(x='S0__36', y='maj__36'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__33','temp1__391')
# [add(x='a__33', y='temp1__391')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__33','S1__36'),add('ch__36','temp1__294'))
# [add(x=add(x='e__33', y='S1__36'), y=add(x='ch__36', y='temp1__294')), add(x='S1__36', y=add(x='e__33', y=add(x='ch__36', y='temp1__294')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__36')
# [not_(x='e__36')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__144',add('S0__35','maj__35'))
# [add(x='temp1__144', y=add(x='S0__35', y='maj__35'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__32','temp1__144')
# [add(x='a__32', y='temp1__144')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__32','S1__35'),'ch__35'),add('value__60','literal.23452'))
# [add(x=add(x=add(x='e__32', y='S1__35'), y='ch__35'), y=add(x='value__60', y='literal.23452')), add(x='ch__35', y=add(x=add(x='e__32', y='S1__35'), y=add(x='value__60', y='literal.23452'))), add(x='e__32', y=add(x='ch__35', y=add(x='S1__35', y=add(x='value__60', y='literal.23452')))), add(x=add(x='literal.23452', y=add(x='S1__35', y='ch__35')), y=add(x='e__32', y='value__60'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__35')
# [not_(x='e__35')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__394',add('S0__34','maj__34'))
# [add(x='temp1__394', y=add(x='S0__34', y='maj__34'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__31','temp1__394')
# [add(x='a__31', y='temp1__394')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__31','S1__34'),add('ch__34','temp1__292'))
# [add(x=add(x='e__31', y='S1__34'), y=add(x='ch__34', y='temp1__292')), add(x='S1__34', y=add(x='e__31', y=add(x='ch__34', y='temp1__292')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__34')
# [not_(x='e__34')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__397',add('S0__33','maj__33'))
# [add(x='temp1__397', y=add(x='S0__33', y='maj__33'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__30','temp1__397')
# [add(x='a__30', y='temp1__397')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__30','S1__33'),add('ch__33','temp1__291'))
# [add(x=add(x='e__30', y='S1__33'), y=add(x='ch__33', y='temp1__291')), add(x='S1__33', y=add(x='e__30', y=add(x='ch__33', y='temp1__291')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__33')
# [not_(x='e__33')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__132',add('S0__32','maj__32'))
# [add(x='temp1__132', y=add(x='S0__32', y='maj__32'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__29','temp1__132')
# [add(x='a__29', y='temp1__132')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e
))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__28')
# [not_(x='e__28')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__112',add('S0__27','maj__27'))
# [add(x='temp1__112', y=add(x='S0__27', y='maj__27'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__24','temp1__112')
# [add(x='a__24', y='temp1__112')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__24','S1__27'),'ch__27'),add('value__36','literal.23396'))
# [add(x=add(x=add(x='e__24', y='S1__27'), y='ch__27'), y=add(x='value__36', y='literal.23396')), add(x='ch__27', y=add(x=add(x='e__24', y='S1__27'), y=add(x='value__36', y='literal.23396'))), add(x='e__24', y=add(x='ch__27', y=add(x='S1__27', y=add(x='value__36', y='literal.23396')))), add(x=add(x='literal.23396', y=add(x='S1__27', y='ch__27')), y=add(x='e__24', y='value__36'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__27')
# [not_(x='e__27')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__400',add('S0__26','maj__26'))
# [add(x='temp1__400', y=add(x='S0__26', y='maj__26'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__23','temp1__400')
# [add(x='a__23', y='temp1__400')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__23','S1__26'),add('ch__26','temp1__284'))
# [add(x=add(x='e__23', y='S1__26'), y=add(x='ch__26', y='temp1__284')), add(x='S1__26', y=add(x='e__23', y=add(x='ch__26', y='temp1__284')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__26')
# [not_(x='e__26')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__104',add('S0__25','maj__25'))
# [add(x='temp1__104', y=add(x='S0__25', y='maj__25'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__22','temp1__104')
# [add(x='a__22', y='temp1__104')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__22','S1__25'),'ch__25'),add('value__30','literal.23382'))
# [add(x=add(x=add(x='e__22', y='S1__25'), y='ch__25'), y=add(x='value__30', y='literal.23382')), add(x='ch__25', y=add(x=add(x='e__22', y='S1__25'), y=add(x='value__30', y='literal.23382'))), add(x='e__22', y=add(x='ch__25', y=add(x='S1__25', y=add(x='value__30', y='literal.23382')))), add(x=add(x='literal.23382', y=add(x='S1__25', y='ch__25')), y=add(x='e__22', y='value__30'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__25')
# [not_(x='e__25')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__403',add('S0__24','maj__24'))
# [add(x='temp1__403', y=add(x='S0__24', y='maj__24'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__21','temp1__403')
# [add(x='a__21', y='temp1__403')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__21','S1__24'),add('ch__24','temp1__282'))
# [add(x=add(x='e__21', y='S1__24'), y=add(x='ch__24', y='temp1__282')), add(x='S1__24', y=add(x='e__21', y=add(x='ch__24', y='temp1__282')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__24')
# [not_(x='e__24')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__406',add('S0__23','maj__23'))
# [add(x='temp1__406', y=add(x='S0__23', y='maj__23'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__20','temp1__406')
# [add(x='a__20', y='temp1__406')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__20','S1__23'),add('ch__23','temp1__281'))
# [add(x=add(x='e__20', y='S1__23'), y=add(x='ch__23', y='temp1__281')), add(x='S1__23', y=add(x='e__20', y=add(x='ch__23', y='temp1__281')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__23')
# [not_(x='e__23')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__409',add('S0__22','maj__22'))
# [add(x='temp1__409', y=add(x='S0__22', y='maj__22'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__19','temp1__409')
# [add(x='a__19', y='temp1__409')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__19','S1__22'),add('ch__22','temp1__280'))
# [add(x=add(x='e__19', y='S1__22'), y=add(x='ch__22', y='temp1__280')), add(x='S1__22', y=add(x='e__19', y=add(x='ch__22', y='temp1__280')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__22')
# [not_(x='e__22')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__412',add('S0__21','maj__21'))
# [add(x='temp1__412', y=add(x='S0__21', y='maj__21'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__18','temp1__412')
# [add(x='a__18', y='temp1__412')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__18','S1__21'),add('ch__21','temp1__279'))
# [add(x=add(x='e__18', y='S1__21'), y=add(x='ch__21', y='temp1__279')), add(x='S1__21', y=add(x='e__18', y=add(x='ch__21', y='temp1__279')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__21')
# [not_(x='e__21')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__84',add('S0__20','maj__20'))
# [add(x='temp1__84', y=add(x='S0__20', y='maj__20'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__17','temp1__84')
# [add(x='a__17', y='temp1__84')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__17','S1__20'),'ch__20'),add('value__15','literal.23347'))
# [add(x=add(x=add(x='e__17', y='S1__20'), y='ch__20'), y=add(x='value__15', y='literal.23347')), add(x='ch__20', y=add(x=add(x='e__17', y='S1__20'), y=add(x='value__15', y='literal.23347'))), add(x='e__17', y=add(x='ch__20', y=add(x='S1__20', y=add(x='value__15', y='literal.23347')))), add(x=add(x='literal.23347', y=add(x='S1__20', y='ch__20')), y=add(x='e__17', y='value__15'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__20')
# [not_(x='e__20')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__415',add('S0__19','maj__19'))
# [add(x='temp1__415', y=add(x='S0__19', y='maj__19'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__16','temp1__415')
# [add(x='a__16', y='temp1__415')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__16','S1__19'),add('ch__19','temp1__277'))
# [add(x=add(x='e__16', y='S1__19'), y=add(x='ch__19', y='temp1__277')), add(x='S1__19', y=add(x='e__16', y=add(x='ch__19', y='temp1__277')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__19')
# [not_(x='e__19')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__418',add('S0__18','maj__18'))
# [add(x='temp1__418', y=add(x='S0__18', y='maj__18'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__15','temp1__418')
# [add(x='a__15', y='temp1__418')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__15','S1__18'),add('ch__18','temp1__276'))
# [add(x=add(x='e__15', y='S1__18'), y=add(x='ch__18', y='temp1__276')), add(x='S1__18', y=add(x='e__15', y=add(x='ch__18', y='temp1__276')))]
# FunctionName:  __sha256__main
# Input Expr:  add('concat.51560','literal.51398')
# [add(x='concat.51560', y='literal.51398')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51339','literal.51397')
# [add(x='bit_slice.51339', y='literal.51397')]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__18')
# [not_(x='e__18')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__421',add('S0__17','maj__17'))
# [add(x='temp1__421', y=add(x='S0__17', y='maj__17'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__14','temp1__421')
# [add(x='a__14', y='temp1__421')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__90','s_0__45'),add('value__117','s_1__45'))
# [add(x=add(x='value__90', y='s_0__45'), y=add(x='value__117', y='s_1__45')), add(x='s_0__45', y=add(x='value__90', y=add(x='value__117', y='s_1__45')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__87','s_0__44'),add('value__114','s_1__44'))
# [add(x=add(x='value__87', y='s_0__44'), y=add(x='value__114', y='s_1__44')), add(x='s_0__44', y=add(x='value__87', y=add(x='value__114', y='s_1__44')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__14','S1__17'),add('ch__17','temp1__275'))
# [add(x=add(x='e__14', y='S1__17'), y=add(x='ch__17', y='temp1__275')), add(x='S1__17', y=add(x='e__14', y=add(x='ch__17', y='temp1__275')))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51334','literal.51396')
# [add(x='bit_slice.51334', y='literal.51396')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51329','literal.51395')
# [add(x='bit_slice.51329', y='literal.51395')]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__17')
# [not_(x='e__17')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__84','s_0__43'),add('value__111','s_1__43'))
# [add(x=add(x='value__84', y='s_0__43'), y=add(x='value__111', y='s_1__43')), add(x='s_0__43', y=add(x='value__84', y=add(x='value__111', y='s_1__43')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__81','s_0__42'),add('value__108','s_1__42'))
# [add(x=add(x='value__81', y='s_0__42'), y=add(x='value__108', y='s_1__42')), add(x='s_0__42', y=add(x='value__81', y=add(x='value__108', y='s_1__42')))]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__68',add('S0__16','maj__16'))
# [add(x='temp1__68', y=add(x='S0__16', y='maj__16'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__13','temp1__68')
# [add(x='a__13', y='temp1__68')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__13','S1__16'),'ch__16'),add('value__3','literal.23319'))
# [add(x=add(x=add(x='e__13', y='S1__16'), y='ch__16'), y=add(x='value__3', y='literal.23319')), add(x='ch__16', y=add(x=add(x='e__13', y='S1__16'), y=add(x='value__3', y='literal.23319'))), add(x='e__13', y=add(x='ch__16', y=add(x='S1__16', y=add(x='value__3', y='literal.23319')))), add(x=add(x='literal.23319', y=add(x='S1__16', y='ch__16')), y=add(x='e__13', y='value__3'))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51324','literal.51394')
# [add(x='bit_slice.51324', y='literal.51394')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__78','s_0__41'),add('value__105','s_1__41'))
# [add(x=add(x='value__78', y='s_0__41'), y=add(x='value__105', y='s_1__41')), add(x='s_0__41', y=add(x='value__78', y=add(x='value__105', y='s_1__41')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__75','s_0__40'),add('value__102','s_1__40'))
# [add(x=add(x='value__75', y='s_0__40'), y=add(x='value__102', y='s_1__40')), add(x='s_0__40', y=add(x='value__75', y=add(x='value__102', y='s_1__40')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__16')
# [not_(x='e__16')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__424',add('S0__15','maj__15'))
# [add(x='temp1__424', y=add(x='S0__15', y='maj__15'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__12','temp1__424')
# [add(x='a__12', y='temp1__424')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__12','S1__15'),add('ch__15','temp1__273'))
# [add(x=add(x='e__12', y='S1__15'), y=add(x='ch__15', y='temp1__273')), add(x='S1__15', y=add(x='e__12', y=add(x='ch__15', y='temp1__273')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__72','s_0__39'),add('value__99','s_1__39'))
# [add(x=add(x='value__72', y='s_0__39'), y=add(x='value__99', y='s_1__39')), add(x='s_0__39', y=add(x='value__72', y=add(x='value__99', y='s_1__39')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__69','s_0__38'),add('value__96','s_1__38'))
# [add(x=add(x='value__69', y='s_0__38'), y=add(x='value__96', y='s_1__38')), add(x='s_0__38', y=add(x='value__69', y=add(x='value__96', y='s_1__38')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__15')
# [not_(x='e__15')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51319','literal.51393')
# [add(x='bit_slice.51319', y='literal.51393')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__60',add('S0__14','maj__14'))
# [add(x='temp1__60', y=add(x='S0__14', y='maj__14'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__11','temp1__60')
# [add(x='a__11', y='temp1__60')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__11','S1__14'),'ch__14'),add('w_init_im2','literal.23305'))
# [add(x=add(x=add(x='e__11', y='S1__14'), y='ch__14'), y=add(x='w_init_im2', y='literal.23305')), add(x='ch__14', y=add(x=add(x='e__11', y='S1__14'), y=add(x='w_init_im2', y='literal.23305'))), add(x='e__11', y=add(x='ch__14', y=add(x='S1__14', y=add(x='w_init_im2', y='literal.23305')))), add(x=add(x='literal.23305', y=add(x='S1__14', y='ch__14')), y=add(x='e__11', y='w_init_im2'))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__66','s_0__37'),add('value__93','s_1__37'))
# [add(x=add(x='value__66', y='s_0__37'), y=add(x='value__93', y='s_1__37')), add(x='s_0__37', y=add(x='value__66', y=add(x='value__93', y='s_1__37')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__63','s_0__36'),add('value__90','s_1__36'))
# [add(x=add(x='value__63', y='s_0__36'), y=add(x='value__90', y='s_1__36')), add(x='s_0__36', y=add(x='value__63', y=add(x='value__90', y='s_1__36')))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51314','literal.51392')
# [add(x='bit_slice.51314', y='literal.51392')]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__14')
# [not_(x='e__14')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__60','s_0__35'),add('value__87','s_1__35'))
# [add(x=add(x='value__60', y='s_0__35'), y=add(x='value__87', y='s_1__35')), add(x='s_0__35', y=add(x='value__60', y=add(x='value__87', y='s_1__35')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__57','s_0__34'),add('value__84','s_1__34'))
# [add(x=add(x='value__57', y='s_0__34'), y=add(x='value__84', y='s_1__34')), add(x='s_0__34', y=add(x='value__57', y=add(x='value__84', y='s_1__34')))]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__427',add('S0__13','maj__13'))
# [add(x='temp1__427', y=add(x='S0__13', y='maj__13'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__10','temp1__427')
# [add(x='a__10', y='temp1__427')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__10','S1__13'),add('ch__13','temp1__271'))
# [add(x=add(x='e__10', y='S1__13'), y=add(x='ch__13', y='temp1__271')), add(x='S1__13', y=add(x='e__10', y=add(x='ch__13', y='temp1__271')))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51309','literal.51391')
# [add(x='bit_slice.51309', y='literal.51391')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51304','literal.51390')
# [add(x='bit_slice.51304', y='literal.51390')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__54','s_0__33'),add('value__81','s_1__33'))
# [add(x=add(x='value__54', y='s_0__33'), y=add(x='value__81', y='s_1__33')), add(x='s_0__33', y=add(x='value__54', y=add(x='value__81', y='s_1__33')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__51','s_0__32'),add('value__78','s_1__32'))
# [add(x=add(x='value__51', y='s_0__32'), y=add(x='value__78', y='s_1__32')), add(x='s_0__32', y=add(x='value__51', y=add(x='value__78', y='s_1__32')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__13')
# [not_(x='e__13')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__430',add('S0__12','maj__12'))
# [add(x='temp1__430', y=add(x='S0__12', y='maj__12'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__9','temp1__430')
# [add(x='a__9', y='temp1__430')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__9','S1__12'),add('ch__12','temp1__270'))
# [add(x=add(x='e__9', y='S1__12'), y=add(x='ch__12', y='temp1__270')), add(x='S1__12', y=add(x='e__9', y=add(x='ch__12', y='temp1__270')))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51299','literal.51389')
# [add(x='bit_slice.51299', y='literal.51389')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__48','s_0__31'),add('value__75','s_1__31'))
# [add(x=add(x='value__48', y='s_0__31'), y=add(x='value__75', y='s_1__31')), add(x='s_0__31', y=add(x='value__48', y=add(x='value__75', y='s_1__31')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__45','s_0__30'),add('value__72','s_1__30'))
# [add(x=add(x='value__45', y='s_0__30'), y=add(x='value__72', y='s_1__30')), add(x='s_0__30', y=add(x='value__45', y=add(x='value__72', y='s_1__30')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__12')
# [not_(x='e__12')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__48',add('S0__11','maj__11'))
# [add(x='temp1__48', y=add(x='S0__11', y='maj__11'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__8','temp1__48')
# [add(x='a__8', y='temp1__48')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51294','literal.51388')
# [add(x='bit_slice.51294', y='literal.51388')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__8','S1__11'),'ch__11'),add('w_im15__10','literal.23284'))
# [add(x=add(x=add(x='e__8', y='S1__11'), y='ch__11'), y=add(x='w_im15__10', y='literal.23284')), add(x='ch__11', y=add(x=add(x='e__8', y='S1__11'), y=add(x='w_im15__10', y='literal.23284'))), add(x='e__8', y=add(x='ch__11', y=add(x='S1__11', y=add(x='w_im15__10', y='literal.23284')))), add(x=add(x='literal.23284', y=add(x='S1__11', y='ch__11')), y=add(x='e__8', y='w_im15__10'))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__42','s_0__29'),add('value__69','s_1__29'))
# [add(x=add(x='value__42', y='s_0__29'), y=add(x='value__69', y='s_1__29')), add(x='s_0__29', y=add(x='value__42', y=add(x='value__69', y='s_1__29')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__39','s_0__28'),add('value__66','s_1__28'))
# [add(x=add(x='value__39', y='s_0__28'), y=add(x='value__66', y='s_1__28')), add(x='s_0__28', y=add(x='value__39', y=add(x='value__66', y='s_1__28')))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51289','literal.51387')
# [add(x='bit_slice.51289', y='literal.51387')]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__11')
# [not_(x='e__11')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__433',add('S0__10','maj__10'))
# [add(x='temp1__433', y=add(x='S0__10', y='maj__10'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__7','temp1__433')
# [add(x='a__7', y='temp1__433')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__36','s_0__27'),add('value__63','s_1__27'))
# [add(x=add(x='value__36', y='s_0__27'), y=add(x='value__63', y='s_1__27')), add(x='s_0__27', y=add(x='value__36', y=add(x='value__63', y='s_1__27')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__33','s_0__26'),add('value__60','s_1__26'))
# [add(x=add(x='value__33', y='s_0__26'), y=add(x='value__60', y='s_1__26')), add(x='s_0__26', y=add(x='value__33', y=add(x='value__60', y='s_1__26')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__7','S1__10'),add('ch__10','temp1__268'))
# [add(x=add(x='e__7', y='S1__10'), y=add(x='ch__10', y='temp1__268')), add(x='S1__10', y=add(x='e__7', y=add(x='ch__10', y='temp1__268')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__10')
# [not_(x='e__10')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__30','s_0__25'),add('value__57','s_1__25'))
# [add(x=add(x='value__30', y='s_0__25'), y=add(x='value__57', y='s_1__25')), add(x='s_0__25', y=add(x='value__30', y=add(x='value__57', y='s_1__25')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__27','s_0__24'),add('value__54','s_1__24'))
# [add(x=add(x='value__27', y='s_0__24'), y=add(x='value__54', y='s_1__24')), add(x='s_0__24', y=add(x='value__27', y=add(x='value__54', y='s_1__24')))]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__40',add('S0__9','maj__9'))
# [add(x='temp1__40', y=add(x='S0__9', y='maj__9'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__6','temp1__40')
# [add(x='a__6', y='temp1__40')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__6','S1__9'),'ch__9'),add('w_im15__8','literal.23270'))
# [add(x=add(x=add(x='e__6', y='S1__9'), y='ch__9'), y=add(x='w_im15__8', y='literal.23270')), add(x='ch__9', y=add(x=add(x='e__6', y='S1__9'), y=add(x='w_im15__8', y='literal.23270'))), add(x='e__6', y=add(x='ch__9', y=add(x='S1__9', y=add(x='w_im15__8', y='literal.23270')))), add(x=add(x='literal.23270', y=add(x='S1__9', y='ch__9')), y=add(x='e__6', y='w_im15__8'))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51284','literal.51386')
# [add(x='bit_slice.51284', y='literal.51386')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__24','s_0__23'),add('value__51','s_1__23'))
# [add(x=add(x='value__24', y='s_0__23'), y=add(x='value__51', y='s_1__23')), add(x='s_0__23', y=add(x='value__24', y=add(x='value__51', y='s_1__23')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__21','s_0__22'),add('value__48','s_1__22'))
# [add(x=add(x='value__21', y='s_0__22'), y=add(x='value__48', y='s_1__22')), add(x='s_0__22', y=add(x='value__21', y=add(x='value__48', y='s_1__22')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__9')
# [not_(x='e__9')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__436',add('S0__8','maj__8'))
# [add(x='temp1__436', y=add(x='S0__8', y='maj__8'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__5','temp1__436')
# [add(x='a__5', y='temp1__436')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51279','literal.51385')
# [add(x='bit_slice.51279', y='literal.51385')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__5','S1__8'),add('ch__8','temp1__266'))
# [add(x=add(x='e__5', y='S1__8'), y=add(x='ch__8', y='temp1__266')), add(x='S1__8', y=add(x='e__5', y=add(x='ch__8', y='temp1__266')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__18','s_0__21'),add('value__45','s_1__21'))
# [add(x=add(x='value__18', y='s_0__21'), y=add(x='value__45', y='s_1__21')), add(x='s_0__21', y=add(x='value__18', y=add(x='value__45', y='s_1__21')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__15','s_0__20'),add('value__42','s_1__20'))
# [add(x=add(x='value__15', y='s_0__20'), y=add(x='value__42', y='s_1__20')), add(x='s_0__20', y=add(x='value__15', y=add(x='value__42', y='s_1__20')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__8')
# [not_(x='e__8')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51274','literal.51384')
# [add(x='bit_slice.51274', y='literal.51384')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__32',add('S0__7','maj__7'))
# [add(x='temp1__32', y=add(x='S0__7', y='maj__7'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__4','temp1__32')
# [add(x='a__4', y='temp1__32')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__69','S1__7'),'ch__7'),add('w_im15__6','literal.23256'))
# [add(x=add(x=add(x='e__69', y='S1__7'), y='ch__7'), y=add(x='w_im15__6', y='literal.23256')), add(x='ch__7', y=add(x=add(x='e__69', y='S1__7'), y=add(x='w_im15__6', y='literal.23256'))), add(x='e__69', y=add(x='ch__7', y=add(x='S1__7', y=add(x='w_im15__6', y='literal.23256')))), add(x=add(x='literal.23256', y=add(x='S1__7', y='ch__7')), y=add(x='e__69', y='w_im15__6'))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__12','s_0__19'),add('value__39','s_1__19'))
# [add(x=add(x='value__12', y='s_0__19'), y=add(x='value__39', y='s_1__19')), add(x='s_0__19', y=add(x='value__12', y=add(x='value__39', y='s_1__19')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__9','s_0__18'),add('value__36','s_1__18'))
# [add(x=add(x='value__9', y='s_0__18'), y=add(x='value__36', y='s_1__18')), add(x='s_0__18', y=add(x='value__9', y=add(x='value__36', y='s_1__18')))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51269','literal.51383')
# [add(x='bit_slice.51269', y='literal.51383')]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__7')
# [not_(x='e__7')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__6','s_0__17'),add('value__33','s_1__17'))
# [add(x=add(x='value__6', y='s_0__17'), y=add(x='value__33', y='s_1__17')), add(x='s_0__17', y=add(x='value__6', y=add(x='value__33', y='s_1__17')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('value__3','s_0__16'),add('value__30','s_1__16'))
# [add(x=add(x='value__3', y='s_0__16'), y=add(x='value__30', y='s_1__16')), add(x='s_0__16', y=add(x='value__3', y=add(x='value__30', y='s_1__16')))]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__439',add('S0__6','maj__6'))
# [add(x='temp1__439', y=add(x='S0__6', y='maj__6'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__3','temp1__439')
# [add(x='a__3', y='temp1__439')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('e__68','S1__6'),add('ch__6','temp1__264'))
# [add(x=add(x='e__68', y='S1__6'), y=add(x='ch__6', y='temp1__264')), add(x='S1__6', y=add(x='e__68', y=add(x='ch__6', y='temp1__264')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('w_im2__1','s_0__15'),add('value__27','s_1__15'))
# [add(x=add(x='w_im2__1', y='s_0__15'), y=add(x='value__27', y='s_1__15')), add(x='s_0__15', y=add(x='w_im2__1', y=add(x='value__27', y='s_1__15')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('w_init_im2','s_0__14'),add('value__24','s_1__14'))
# [add(x=add(x='w_init_im2', y='s_0__14'), y=add(x='value__24', y='s_1__14')), add(x='s_0__14', y=add(x='w_init_im2', y=add(x='value__24', y='s_1__14')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__6')
# [not_(x='e__6')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__24',add('S0__5','maj__5'))
# [add(x='temp1__24', y=add(x='S0__5', y='maj__5'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__2','temp1__24')
# [add(x='a__2', y='temp1__24')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__67','S1__5'),'ch__5'),add('w_im15__4','literal.23242'))
# [add(x=add(x=add(x='e__67', y='S1__5'), y='ch__5'), y=add(x='w_im15__4', y='literal.23242')), add(x='ch__5', y=add(x=add(x='e__67', y='S1__5'), y=add(x='w_im15__4', y='literal.23242'))), add(x='e__67', y=add(x='ch__5', y=add(x='S1__5', y=add(x='w_im15__4', y='literal.23242')))), add(x=add(x='literal.23242', y=add(x='S1__5', y='ch__5')), y=add(x='e__67', y='w_im15__4'))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('w_im15__12','s_0__13'),add('value__21','s_1__13'))
# [add(x=add(x='w_im15__12', y='s_0__13'), y=add(x='value__21', y='s_1__13')), add(x='s_0__13', y=add(x='w_im15__12', y=add(x='value__21', y='s_1__13')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('w_im15__11','s_0__12'),add('value__18','s_1__12'))
# [add(x=add(x='w_im15__11', y='s_0__12'), y=add(x='value__18', y='s_1__12')), add(x='s_0__12', y=add(x='w_im15__11', y=add(x='value__18', y='s_1__12')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__5')
# [not_(x='e__5')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51264','literal.51382')
# [add(x='bit_slice.51264', y='literal.51382')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__20',add('S0__4','maj__4'))
# [add(x='temp1__20', y=add(x='S0__4', y='maj__4'))]
# FunctionName:  __sha256__main
# Input Expr:  add('a__1','temp1__20')
# [add(x='a__1', y='temp1__20')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('e__66','S1__4'),'ch__4'),add('w_im15__3','literal.23235'))
# [add(x=add(x=add(x='e__66', y='S1__4'), y='ch__4'), y=add(x='w_im15__3', y='literal.23235')), add(x='ch__4', y=add(x=add(x='e__66', y='S1__4'), y=add(x='w_im15__3', y='literal.23235'))), add(x='e__66', y=add(x='ch__4', y=add(x='S1__4', y=add(x='w_im15__3', y='literal.23235')))), add(x=add(x='literal.23235', y=add(x='S1__4', y='ch__4')), y=add(x='e__66', y='w_im15__3'))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('w_im15__10','s_0__11'),add('value__15','s_1__11'))
# [add(x=add(x='w_im15__10', y='s_0__11'), y=add(x='value__15', y='s_1__11')), add(x='s_0__11', y=add(x='w_im15__10', y=add(x='value__15', y='s_1__11')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('w_im15__9','s_0__10'),add('value__12','s_1__10'))
# [add(x=add(x='w_im15__9', y='s_0__10'), y=add(x='value__12', y='s_1__10')), add(x='s_0__10', y=add(x='w_im15__9', y=add(x='value__12', y='s_1__10')))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51259','literal.51381')
# [add(x='bit_slice.51259', y='literal.51381')]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__69')
# [not_(x='e__69')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('w_im15__8','s_0__9'),add('value__9','s_1__9'))
# [add(x=add(x='w_im15__8', y='s_0__9'), y=add(x='value__9', y='s_1__9')), add(x='s_0__9', y=add(x='w_im15__8', y=add(x='value__9', y='s_1__9')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('w_im15__7','s_0__8'),add('value__6','s_1__8'))
# [add(x=add(x='w_im15__7', y='s_0__8'), y=add(x='value__6', y='s_1__8')), add(x='s_0__8', y=add(x='w_im15__7', y=add(x='value__6', y='s_1__8')))]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__330',add('S0__3','maj__3'))
# [add(x='temp1__330', y=add(x='S0__3', y='maj__3'))]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__330','b__67')
# [add(x='temp1__330', y='b__67')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('S1__3','ch__3'),'temp1__329')
# [add(x=add(x='S1__3', y='ch__3'), y='temp1__329'), add(x='ch__3', y=add(x='S1__3', y='temp1__329'))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51254','literal.51380')
# [add(x='bit_slice.51254', y='literal.51380')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51249','literal.51379')
# [add(x='bit_slice.51249', y='literal.51379')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('w_im15__6','s_0__7'),add('value__3','s_1__7'))
# [add(x=add(x='w_im15__6', y='s_0__7'), y=add(x='value__3', y='s_1__7')), add(x='s_0__7', y=add(x='w_im15__6', y=add(x='value__3', y='s_1__7')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('w_im15__5','s_0__6'),add('w_im2__1','s_1__6'))
# [add(x=add(x='w_im15__5', y='s_0__6'), y=add(x='w_im2__1', y='s_1__6')), add(x='s_0__6', y=add(x='w_im15__5', y=add(x='w_im2__1', y='s_1__6')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('e__68')
# [not_(x='e__68')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__334',add('S0__2','maj__2'))
# [add(x='temp1__334', y=add(x='S0__2', y='maj__2'))]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__334','c__67')
# [add(x='temp1__334', y='c__67')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('S1__2','ch__2'),add('w_im15__1','temp1__331'))
# [add(x=add(x='S1__2', y='ch__2'), y=add(x='w_im15__1', y='temp1__331')), add(x='ch__2', y=add(x='S1__2', y=add(x='w_im15__1', y='temp1__331')))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51244','literal.51378')
# [add(x='bit_slice.51244', y='literal.51378')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('w_im15__4','s_0__5'),add('w_init_im2','s_1__5'))
# [add(x=add(x='w_im15__4', y='s_0__5'), y=add(x='w_init_im2', y='s_1__5')), add(x='s_0__5', y=add(x='w_im15__4', y=add(x='w_init_im2', y='s_1__5')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('w_im15__3','s_0__4'),add('w_im15__12','s_1__4'))
# [add(x=add(x='w_im15__3', y='s_0__4'), y=add(x='w_im15__12', y='s_1__4')), add(x='s_0__4', y=add(x='w_im15__3', y=add(x='w_im15__12', y='s_1__4')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.51191')
# [not_(x='add.51191')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51239','literal.51377')
# [add(x='bit_slice.51239', y='literal.51377')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51234','literal.51376')
# [add(x='bit_slice.51234', y='literal.51376')]
# FunctionName:  __sha256__main
# Input Expr:  not_('bit_slice.51192')
# [not_(x='bit_slice.51192')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51189','literal.51367')
# [add(x='bit_slice.51189', y='literal.51367')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__338',add('S0__1','maj__1'))
# [add(x='temp1__338', y=add(x='S0__1', y='maj__1'))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('w_im15__2','s_0__3'),add('w_im15__11','s_1__3'))
# [add(x=add(x='w_im15__2', y='s_0__3'), y=add(x='w_im15__11', y='s_1__3')), add(x='s_0__3', y=add(x='w_im15__2', y=add(x='w_im15__11', y='s_1__3')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('w_im15__1','s_0__2'),add('w_im15__10','s_1__2'))
# [add(x=add(x='w_im15__1', y='s_0__2'), y=add(x='w_im15__10', y='s_1__2')), add(x='s_0__2', y=add(x='w_im15__1', y=add(x='w_im15__10', y='s_1__2')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('S1__1','ch__1'),'temp1__337')
# [add(x=add(x='S1__1', y='ch__1'), y='temp1__337'), add(x='ch__1', y=add(x='S1__1', y='temp1__337'))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51229','literal.51375')
# [add(x='bit_slice.51229', y='literal.51375')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('w_init_im15','s_0__1'),add('w_im15__9','s_1__1'))
# [add(x=add(x='w_init_im15', y='s_0__1'), y=add(x='w_im15__9', y='s_1__1')), add(x='s_0__1', y=add(x='w_init_im15', y=add(x='w_im15__9', y='s_1__1')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('bit_slice.16221','s_0'),add('w_im15__8','s_1'))
# [add(x=add(x='bit_slice.16221', y='s_0'), y=add(x='w_im15__8', y='s_1')), add(x='s_0', y=add(x='bit_slice.16221', y=add(x='w_im15__8', y='s_1')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.51181')
# [not_(x='add.51181')]
# FunctionName:  __sha256__main
# Input Expr:  add('temp1__323','temp2')
# [add(x='temp1__323', y='temp2')]
# FunctionName:  __sha256__main
# Input Expr:  add('concat.51540','literal.51365')
# [add(x='concat.51540', y='literal.51365')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51557','literal.51374')
# [add(x='bit_slice.51557', y='literal.51374')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51555','literal.51373')
# [add(x='bit_slice.51555', y='literal.51373')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51553','literal.51372')
# [add(x='bit_slice.51553', y='literal.51372')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51551','literal.51371')
# [add(x='bit_slice.51551', y='literal.51371')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51549','literal.51370')
# [add(x='bit_slice.51549', y='literal.51370')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51547','literal.51369')
# [add(x='bit_slice.51547', y='literal.51369')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51545','literal.51368')
# [add(x='bit_slice.51545', y='literal.51368')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51543','literal.51366')
# [add(x='bit_slice.51543', y='literal.51366')]
# FunctionName:  __sha256__main
# Input Expr:  not_('bit_slice.51564')
# [not_(x='bit_slice.51564')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51537','literal.51364')
# [add(x='bit_slice.51537', y='literal.51364')]

# %%
# The subsequent part is for getting SDC results and testing GNN

# %%
def get_sdc_from_graph(ir_input_path, delay_model='sky130', 
               Schedule_Method="SDC", clock_period_ps=None, clock_margin_precent=None, 
               pipeline_stages=None, period_relaxation_percent=None):
    
    command_executable = '/home/miao/xls/bazel-bin/xls/tools/RL_main'
    ir_unify_name_out = ir_input_path.replace('.ir','.unify.ir')
    json_output_path = ir_input_path.replace('.ir','.json')
    ir_output_path = ir_input_path.replace('.ir','_substitution.ir')
    schedule_result_path = ir_input_path.replace('.ir', '_schedule.txt')
    output_verilog_path = json_output_path.replace(".json", ".v")
    output_schedule_ir_path = ir_output_path.replace(".ir", "_schedule.ir")
    
    run_unify_name(ir_input_path, ir_unify_name_out)
    #Get rewrite json file from IR and selector model
    G, TopFunctionName = gen_json_from_ir(ir_unify_name_out, json_output_path)
    #Run cc rewriter to implement the rewrite
#     run_rewriter(command_executable, ir_unify_name_out, json_output_path, ir_output_path)
    #Run SDC with the new IR and generate result.
    run_sdc_scheduler(ir_unify_name_out, output_verilog_path, schedule_result_path, output_schedule_ir_path, 
                      delay_model, TopFunctionName, clock_period_ps, clock_margin_precent, 
                      pipeline_stages, period_relaxation_percent)
    #Collect the scheduling result to a graph
    G_schedule, max_stage_latency, stage_num, register_count = get_graph_with_scheduling(output_schedule_ir_path, schedule_result_path)
    
    return G_schedule, max_stage_latency, stage_num, register_count

G, max_stage_latency, stage_num, register_count = get_sdc_from_graph("/home/miao/xls/work_space/Sha256/sha256.opt.ir", clock_period_ps=1000)
print("Max Pipeline Latency: ", max_stage_latency)
# Out:
# Name Unification Run Done.
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.
]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51349','literal.51598')
# [add(x='bit_slice.51349', y='literal.51598')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22621','literal.23171')
# [add(x='add.22621', y='literal.23171')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22617',add('concat.34765','xor.22616'))
# [add(x='add.22617', y=add(x='concat.34765', y='xor.22616'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22360','add.22617')
# [add(x='add.22360', y='add.22617')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.22361','concat.34727'),'xor.22604'),add('add.18490','literal.23634'))
# [add(x=add(x=add(x='add.22361', y='concat.34727'), y='xor.22604'), y=add(x='add.18490', y='literal.23634')), add(x='xor.22604', y=add(x=add(x='add.22361', y='concat.34727'), y=add(x='add.18490', y='literal.23634'))), add(x='add.22361', y=add(x='xor.22604', y=add(x='concat.34727', y=add(x='add.18490', y='literal.23634')))), add(x=add(x='literal.23634', y=add(x='concat.34727', y='xor.22604')), y=add(x='add.22361', y='add.18490'))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51354','literal.51597')
# [add(x='bit_slice.51354', y='literal.51597')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22556','literal.23656')
# [add(x='add.22556', y='literal.23656')]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.22556')
# [not_(x='add.22556')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51404',add('concat.34689','xor.22551'))
# [add(x='add.51404', y=add(x='concat.34689', y='xor.22551'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22295','add.51404')
# [add(x='add.22295', y='add.51404')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.22296','concat.34651'),add('xor.22539','concat.51343'))
# [add(x=add(x='add.22296', y='concat.34651'), y=add(x='xor.22539', y='concat.51343')), add(x='concat.34651', y=add(x='add.22296', y=add(x='xor.22539', y='concat.51343')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.22491')
# [not_(x='add.22491')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51407',add('concat.34613','xor.22486'))
# [add(x='add.51407', y=add(x='concat.34613', y='xor.22486'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22230','add.51407')
# [add(x='add.22230', y='add.51407')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.22231','concat.34575'),add('xor.22474','concat.51338'))
# [add(x=add(x='add.22231', y='concat.34575'), y=add(x='xor.22474', y='concat.51338')), add(x='concat.34575', y=add(x='add.22231', y=add(x='xor.22474', y='concat.51338')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.22426')
# [not_(x='add.22426')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51410',add('concat.34537','xor.22421'))
# [add(x='add.51410', y=add(x='concat.34537', y='xor.22421'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22165','add.51410')
# [add(x='add.22165', y='add.51410')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.22166','concat.34499'),add('xor.22409','concat.51333'))
# [add(x=add(x='add.22166', y='concat.34499'), y=add(x='xor.22409', y='concat.51333')), add(x='concat.34499', y=add(x='add.22166', y=add(x='xor.22409', y='concat.51333')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.22361')
# [not_(x='add.22361')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22357',add('concat.34461','xor.22356'))
# [add(x='add.22357', y=add(x='concat.34461', y='xor.22356'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22100','add.22357')
# [add(x='add.22100', y='add.22357')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.22101','concat.34423'),'xor.22344'),add('add.18294','literal.23606'))
# [add(x=add(x=add(x='add.22101', y='concat.34423'), y='xor.22344'), y=add(x='add.18294', y='literal.23606')), add(x='xor.22344', y=add(x=add(x='add.22101', y='concat.34423'), y=add(x='add.18294', y='literal.23606'))), add(x='add.22101', y=add(x='xor.22344', y=add(x='concat.34423', y=add(x='add.18294', y='literal.23606')))), add(x=add(x='literal.23606', y=add(x='concat.34423', y='xor.22344')), y=add(x='add.22101', y='add.18294'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.22296')
# [not_(x='add.22296')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51413',add('concat.34385','xor.22291'))
# [add(x='add.51413', y=add(x='concat.34385', y='xor.22291'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22035','add.51413')
# [add(x='add.22035', y='add.51413')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.22036','concat.34347'),add('xor.22279','concat.51328'))
# [add(x=add(x='add.22036', y='concat.34347'), y=add(x='xor.22279', y='concat.51328')), add(x='concat.34347', y=add(x='add.22036', y=add(x='xor.22279', y='concat.51328')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.22231')
# [not_(x='add.22231')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22227',add('concat.34309','xor.22226'))
# [add(x='add.22227', y=add(x='concat.34309', y='xor.22226'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21970','add.22227')
# [add(x='add.21970', y='add.22227')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.21971','concat.34271'),'xor.22214'),add('add.18196','literal.23592'))
# [add(x=add(x=add(x='add.21971', y='concat.34271'), y='xor.22214'), y=add(x='add.18196', y='literal.23592')), add(x='xor.22214', y=add(x=add(x='add.21971', y='concat.34271'), y=add(x='add.18196', y='literal.23592'))), add(x='add.21971', y=add(x='xor.22214', y=add(x='concat.34271', y=add(x='add.18196', y='literal.23592')))), add(x=add(x='literal.23592', y=add(x='concat.34271', y='xor.22214')), y=add(x='add.21971', y='add.18196'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.22166')
# [not_(x='add.22166')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22162',add('concat.34233','xor.22161'))
# [add(x='add.22162', y=add(x='concat.34233', y='xor.22161'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21905','add.22162')
# [add(x='add.21905', y='add.22162')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.21906','concat.34195'),'xor.22149'),add('add.18147','literal.23585'))
# [add(x=add(x=add(x='add.21906', y='concat.34195'), y='xor.22149'), y=add(x='add.18147', y='literal.23585')), add(x='xor.22149', y=add(x=add(x='add.21906', y='concat.34195'), y=add(x='add.18147', y='literal.23585'))), add(x='add.21906', y=add(x='xor.22149', y=add(x='concat.34195', y=add(x='add.18147', y='literal.23585')))), add(x=add(x='literal.23585', y=add(x='concat.34195', y='xor.22149')), y=add(x='add.21906', y='add.18147'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.22101')
# [not_(x='add.22101')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51416',add('concat.34157','xor.22096'))
# [add(x='add.51416', y=add(x='concat.34157', y='xor.22096'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21840','add.51416')
# [add(x='add.21840', y='add.51416')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.21841','concat.34119'),add('xor.22084','concat.51323'))
# [add(x=add(x='add.21841', y='concat.34119'), y=add(x='xor.22084', y='concat.51323')), add(x='concat.34119', y=add(x='add.21841', y=add(x='xor.22084', y='concat.51323')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.22036')
# [not_(x='add.22036')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.22032',add('concat.34081','xor.22031'))
# [add(x='add.22032', y=add(x='concat.34081', y='xor.22031'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21775','add.22032')
# [add(x='add.21775', y='add.22032')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.21776','concat.34043'),'xor.22019'),add('add.18049','literal.23571'))
# [add(x=add(x=add(x='add.21776', y='concat.34043'), y='xor.22019'), y=add(x='add.18049', y='literal.23571')), add(x='xor.22019', y=add(x=add(x='add.21776', y='concat.34043'), y=add(x='add.18049', y='literal.23571'))), add(x='add.21776', y=add(x='xor.22019', y=add(x='concat.34043', y=add(x='add.18049', y='literal.23571')))), add(x=add(x='literal.23571', y=add(x='concat.34043', y='xor.22019')), y=add(x='add.21776', y='add.18049'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.21971')
# [not_(x='add.21971')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21967',add('concat.34005','xor.21966'))
# [add(x='add.21967', y=add(x='concat.34005', y='xor.21966'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.
]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20996','concat.33131'),'xor.21239'),add('add.17461','literal.23487'))
# [add(x=add(x=add(x='add.20996', y='concat.33131'), y='xor.21239'), y=add(x='add.17461', y='literal.23487')), add(x='xor.21239', y=add(x=add(x='add.20996', y='concat.33131'), y=add(x='add.17461', y='literal.23487'))), add(x='add.20996', y=add(x='xor.21239', y=add(x='concat.33131', y=add(x='add.17461', y='literal.23487')))), add(x=add(x='literal.23487', y=add(x='concat.33131', y='xor.21239')), y=add(x='add.20996', y='add.17461'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.21191')
# [not_(x='add.21191')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21187',add('concat.33093','xor.21186'))
# [add(x='add.21187', y=add(x='concat.33093', y='xor.21186'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20930','add.21187')
# [add(x='add.20930', y='add.21187')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20931','concat.33055'),'xor.21174'),add('add.17412','literal.23480'))
# [add(x=add(x=add(x='add.20931', y='concat.33055'), y='xor.21174'), y=add(x='add.17412', y='literal.23480')), add(x='xor.21174', y=add(x=add(x='add.20931', y='concat.33055'), y=add(x='add.17412', y='literal.23480'))), add(x='add.20931', y=add(x='xor.21174', y=add(x='concat.33055', y=add(x='add.17412', y='literal.23480')))), add(x=add(x='literal.23480', y=add(x='concat.33055', y='xor.21174')), y=add(x='add.20931', y='add.17412'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.21126')
# [not_(x='add.21126')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51437',add('concat.33017','xor.21121'))
# [add(x='add.51437', y=add(x='concat.33017', y='xor.21121'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20865','add.51437')
# [add(x='add.20865', y='add.51437')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.20866','concat.32979'),add('xor.21109','concat.51288'))
# [add(x=add(x='add.20866', y='concat.32979'), y=add(x='xor.21109', y='concat.51288')), add(x='concat.32979', y=add(x='add.20866', y=add(x='xor.21109', y='concat.51288')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.21061')
# [not_(x='add.21061')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.21057',add('concat.32941','xor.21056'))
# [add(x='add.21057', y=add(x='concat.32941', y='xor.21056'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20800','add.21057')
# [add(x='add.20800', y='add.21057')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20801','concat.32903'),'xor.21044'),add('add.17314','literal.23466'))
# [add(x=add(x=add(x='add.20801', y='concat.32903'), y='xor.21044'), y=add(x='add.17314', y='literal.23466')), add(x='xor.21044', y=add(x=add(x='add.20801', y='concat.32903'), y=add(x='add.17314', y='literal.23466'))), add(x='add.20801', y=add(x='xor.21044', y=add(x='concat.32903', y=add(x='add.17314', y='literal.23466')))), add(x=add(x='literal.23466', y=add(x='concat.32903', y='xor.21044')), y=add(x='add.20801', y='add.17314'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20996')
# [not_(x='add.20996')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51440',add('concat.32865','xor.20991'))
# [add(x='add.51440', y=add(x='concat.32865', y='xor.20991'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20735','add.51440')
# [add(x='add.20735', y='add.51440')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.20736','concat.32827'),add('xor.20979','concat.51283'))
# [add(x=add(x='add.20736', y='concat.32827'), y=add(x='xor.20979', y='concat.51283')), add(x='concat.32827', y=add(x='add.20736', y=add(x='xor.20979', y='concat.51283')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20931')
# [not_(x='add.20931')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20927',add('concat.32789','xor.20926'))
# [add(x='add.20927', y=add(x='concat.32789', y='xor.20926'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20670','add.20927')
# [add(x='add.20670', y='add.20927')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20671','concat.32751'),'xor.20914'),add('add.17216','literal.23452'))
# [add(x=add(x=add(x='add.20671', y='concat.32751'), y='xor.20914'), y=add(x='add.17216', y='literal.23452')), add(x='xor.20914', y=add(x=add(x='add.20671', y='concat.32751'), y=add(x='add.17216', y='literal.23452'))), add(x='add.20671', y=add(x='xor.20914', y=add(x='concat.32751', y=add(x='add.17216', y='literal.23452')))), add(x=add(x='literal.23452', y=add(x='concat.32751', y='xor.20914')), y=add(x='add.20671', y='add.17216'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20866')
# [not_(x='add.20866')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51443',add('concat.32713','xor.20861'))
# [add(x='add.51443', y=add(x='concat.32713', y='xor.20861'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20605','add.51443')
# [add(x='add.20605', y='add.51443')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.20606','concat.32675'),add('xor.20849','concat.51278'))
# [add(x=add(x='add.20606', y='concat.32675'), y=add(x='xor.20849', y='concat.51278')), add(x='concat.32675', y=add(x='add.20606', y=add(x='xor.20849', y='concat.51278')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20801')
# [not_(x='add.20801')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51446',add('concat.32637','xor.20796'))
# [add(x='add.51446', y=add(x='concat.32637', y='xor.20796'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20540','add.51446')
# [add(x='add.20540', y='add.51446')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.20541','concat.32599'),add('xor.20784','concat.51273'))
# [add(x=add(x='add.20541', y='concat.32599'), y=add(x='xor.20784', y='concat.51273')), add(x='concat.32599', y=add(x='add.20541', y=add(x='xor.20784', y='concat.51273')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20736')
# [not_(x='add.20736')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20732',add('concat.32561','xor.20731'))
# [add(x='add.20732', y=add(x='concat.32561', y='xor.20731'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20475','add.20732')
# [add(x='add.20475', y='add.20732')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20476','concat.32523'),'xor.20719'),add('add.17069','literal.23431'))
# [add(x=add(x=add(x='add.20476', y='concat.32523'), y='xor.20719'), y=add(x='add.17069', y='literal.23431')), add(x='xor.20719', y=add(x=add(x='add.20476', y='concat.32523'), y=add(x='add.17069', y='literal.23431'))), add(x='add.20476', y=add(x='xor.20719', y=add(x='concat.32523', y=add(x='add.17069', y='literal.23431')))), add(x=add(x='literal.23431', y=add(x='concat.32523', y='xor.20719')), y=add(x='add.20476', y='add.17069'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20671')
# [not_(x='add.20671')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20667',add('concat.32485','xor.20666'))
# [add(x='add.20667', y=add(x='concat.32485', y='xor.20666'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20410','add.20667')
# [add(x='add.20410', y='add.20667')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20411','concat.32447'),'xor.20654'),add('add.17020','literal.23424'))
# [add(x=add(x=add(x='add.20411', y='concat.32447'), y='xor.20654'), y=add(x='add.17020', y='literal.23424')), add(x='xor.20654', y=add(x=add(x='add.20411', y='concat.32447'), y=add(x='add.17020', y='literal.23424'))), add(x='add.20411', y=add(x='xor.20654', y=add(x='concat.32447', y=add(x='add.17020', y='literal.23424')))), add(x=add(x='literal.23424', y=add(x='concat.32447', y='xor.20654')), y=add(x='add.20411', y='add.17020'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20606')
# [not_(x='add.20606')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20602',add('concat.32409','xor.20601'))
# [add(x='add.20602', y=add(x='concat.32409', y='xor.20601'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20345','add.20602')
# [add(x='add.20345', y='add.20602')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20346','concat.32371'),'xor.20589'),add('add.16971','literal.23417'))
# [add(x=add(x=add(x='add.20346', y='concat.32371'), y='xor.20589'), y=add(x='add.16971', y='literal.23417')), add(x='xor.20589', y=add(x=add(x='add.20346', y='concat.32371'), y=add(x='add.16971', y='literal.23417'))), add(x='add.20346', y=add(x='xor.20589', y=add(x='concat.32371', y=add(x='add.16971', y='literal.23417')))), add(x=add(x='literal.23417', y=add(x='concat.32371', y='xor.20589')), y=add(x='add.20346', y='add.16971'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20541')
# [not_(x='add.20541')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20537',add('concat.32333','xor.20536'))
# [add(x='add.20537', y=add(x='concat.32333', y='xor.20536'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20280','add.20537')
# [add(x='add.20280', y='add.20537')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20281','concat.32295'),'xor.20524'),add('add.16922','literal.23410'))
# [add(x=add(x=add(x='add.20281', y='concat.32295'), y='xor.20524'), y=add(x='add.16922', y='literal.23410')), add(x='xor.20524', y=add(x=add(x='add.20281', y='concat.32295'), y=add(x='add.16922', y='literal.23410'))), add(x='add.20281', y=add(x='xor.20524', y=add(x='concat.32295', y=add(x='add.16922', y='literal.23410')))), add(x=add(x='literal.23410', y=add(x='concat.32295', y='xor.20524')), y=add(x='add.20281', y='add.16922'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20476')
# [not_(x='add.20476')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20472',add('concat.32257','xor.20471'))
# [add(x='add.20472', y=add(x='concat.32257', y='xor.20471'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20215','add.20472')
# [add(x='add.20215', y='add.20472')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20216','concat.32219'),'xor.20459'),add('add.16873','literal.23403'))
# [add(x=add(x=add(x='add.20216', y='concat.32219'), y='xor.20459'), y=add(x='add.16873', y='literal.23403')), add(x='xor.20459', y=add(x=add(x='add.20216', y='concat.32219'), y=add(x='add.16873', y='literal.23403'))), add(x='add.20216', y=add(x='xor.20459', y=add(x='concat.32219', y=add(x='add.16873', y='literal.23403')))), add(x=add(x='literal.23403', y=add(x='concat.32219', y='xor.20459')), y=add(x='add.20216', y='add.16873'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20411')
# [not_(x='add.20411')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20407',add('concat.32181','xor.20406'))
# [add(x='add.20407', y=add(x='concat.32181', y='xor.20406'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20150','add.20407')
# [add(x='add.20150', y='add.20407')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20151','concat.32143'),'xor.20394'),add('add.16824','literal.23396'))
# [add(x=add(x=add(x='add.20151', y='concat.32143'), y='xor.20394'), y=add(x='add.16824', y='literal.23396')), add(x='xor.20394', y=add(x=add(x='add.20151', y='concat.32143'), y=add(x='add.16824', y='literal.23396'))), add(x='add.20151', y=add(x='xor.20394', y=add(x='concat.32143', y=add(x='add.16824', y='literal.23396')))), add(x=add(x='literal.23396', y=add(x='concat.32143', y='xor.20394')), y=add(x='add.20151', y='add.16824'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20346')
# [not_(x='add.20346')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51449',add('concat.32105','xor.20341'))
# [add(x='add.51449', y=add(x='concat.32105', y='xor.20341'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20085','add.51449')
# [add(x='add.20085', y='add.51449')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.20086','concat.32067'),add('xor.20329','concat.51268'))
# [add(x=add(x='add.20086', y='concat.32067'), y=add(x='xor.20329', y='concat.51268')), add(x='concat.32067', y=add(x='add.20086', y=add(x='xor.20329', y='concat.51268')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20281')
# [not_(x='add.20281')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20277',add('concat.32029','xor.20276'))
# [add(x='add.20277', y=add(x='concat.32029', y='xor.20276'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.20020','add.20277')
# [add(x='add.20020', y='add.20277')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.20021','concat.31991'),'xor.20264'),add('add.16726','literal.23382'))
# [add(x=add(x=add(x='add.20021', y='concat.31991'), y='xor.20264'), y=add(x='add.16726', y='literal.23382')), add(x='xor.20264', y=add(x=add(x='add.20021', y='concat.31991'), y=add(x='add.16726', y='literal.23382'))), add(x='add.20021', y=add(x='xor.20264', y=add(x='concat.31991', y=add(x='add.16726', y='literal.23382')))), add(x=add(x='literal.23382', y=add(x='concat.31991', y='xor.20264')), y=add(x='add.20021', y='add.16726'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20216')
# [not_(x='add.20216')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51452',add('concat.31953','xor.20211'))
# [add(x='add.51452', y=add(x='concat.31953', y='xor.20211'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19955','add.51452')
# [add(x='add.19955', y='add.51452')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.19956','concat.31915'),add('xor.20199','concat.51263'))
# [add(x=add(x='add.19956', y='concat.31915'), y=add(x='xor.20199', y='concat.51263')), add(x='concat.31915', y=add(x='add.19956', y=add(x='xor.20199', y='concat.51263')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20151')
# [not_(x='add.20151')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51455',add('concat.31877','xor.20146'))
# [add(x='add.51455', y=add(x='concat.31877', y='xor.20146'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19890','add.51455')
# [add(x='add.19890', y='add.51455')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.19891','concat.31839'),add('xor.20134','concat.51258'))
# [add(x=add(x='add.19891', y='concat.31839'), y=add(x='xor.20134', y='concat.51258')), add(x='concat.31839', y=add(x='add.19891', y=add(x='xor.20134', y='concat.51258')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20086')
# [not_(x='add.20086')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51458',add('concat.31801','xor.20081'))
# [add(x='add.51458', y=add(x='concat.31801', y='xor.20081'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19825','add.51458')
# [add(x='add.19825', y='add.51458')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.19826','concat.31763'),add('xor.20069','concat.51253'))
# [add(x=add(x='add.19826', y='concat.31763'), y=add(x='xor.20069', y='concat.51253')), add(x='concat.31763', y=add(x='add.19826', y=add(x='xor.20069', y='concat.51253')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.20021')
# [not_(x='add.20021')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51461',add('concat.31725','xor.20016'))
# [add(x='add.51461', y=add(x='concat.31725', y='xor.20016'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19760','add.51461')
# [add(x='add.19760', y='add.51461')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.19761','concat.31687'),add('xor.20004','concat.51248'))
# [add(x=add(x='add.19761', y='concat.31687'), y=add(x='xor.20004', y='concat.51248')), add(x='concat.31687', y=add(x='add.19761', y=add(x='xor.20004', y='concat.51248')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.19956')
# [not_(x='add.19956')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19952',add('concat.31649','xor.19951'))
# [add(x='add.19952', y=add(x='concat.31649', y='xor.19951'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19695','add.19952')
# [add(x='add.19695', y='add.19952')]
# FunctionName:  __sha256__main
# Input Expr:  add(add(add('add.19696','concat.31611'),'xor.19939'),add('add.16481','literal.23347'))
# [add(x=add(x=add(x='add.19696', y='concat.31611'), y='xor.19939'), y=add(x='add.16481', y='literal.23347')), add(x='xor.19939', y=add(x=add(x='add.19696', y='concat.31611'), y=add(x='add.16481', y='literal.23347'))), add(x='add.19696', y=add(x='xor.19939', y=add(x='concat.31611', y=add(x='add.16481', y='literal.23347')))), add(x=add(x='literal.23347', y=add(x='concat.31611', y='xor.19939')), y=add(x='add.19696', y='add.16481'))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.19891')
# [not_(x='add.19891')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.51464',add('concat.31573','xor.19886'))
# [add(x='add.51464', y=add(x='concat.31573', y='xor.19886'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.19630','add.51464')
# [add(x='add.19630', y='add.51464')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('add.19631','concat.31535'),add('xor.19874','concat.51243'))
# [add(x=add(x='add.19631', y='concat.31535'), y=add(x='xor.19874', y='concat.51243')), add(x='concat.31535', y=add(x='add.19631', y=add(x='xor.19874', y='concat.51243')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.
]
# FunctionName:  __sha256__main
# Input Expr:  add('add.37949',add('concat.30281','xor.18781'))
# [add(x='add.37949', y=add(x='concat.30281', y='xor.18781'))]
# FunctionName:  __sha256__main
# Input Expr:  add('add.37949','literal.51596')
# [add(x='add.37949', y='literal.51596')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('concat.30243','xor.18769'),add('bit_slice.16223','literal.37955'))
# [add(x=add(x='concat.30243', y='xor.18769'), y=add(x='bit_slice.16223', y='literal.37955')), add(x='xor.18769', y=add(x='concat.30243', y=add(x='bit_slice.16223', y='literal.37955')))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51244','literal.51378')
# [add(x='bit_slice.51244', y='literal.51378')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('bit_slice.16226','concat.27508'),add('bit_slice.16235','concat.27525'))
# [add(x=add(x='bit_slice.16226', y='concat.27508'), y=add(x='bit_slice.16235', y='concat.27525')), add(x='concat.27508', y=add(x='bit_slice.16226', y=add(x='bit_slice.16235', y='concat.27525')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('bit_slice.16225','concat.27446'),add('bit_slice.16234','concat.27463'))
# [add(x=add(x='bit_slice.16225', y='concat.27446'), y=add(x='bit_slice.16234', y='concat.27463')), add(x='concat.27446', y=add(x='bit_slice.16225', y=add(x='bit_slice.16234', y='concat.27463')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.51191')
# [not_(x='add.51191')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51239','literal.51377')
# [add(x='bit_slice.51239', y='literal.51377')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51234','literal.51376')
# [add(x='bit_slice.51234', y='literal.51376')]
# FunctionName:  __sha256__main
# Input Expr:  not_('bit_slice.51192')
# [not_(x='bit_slice.51192')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51189','literal.51367')
# [add(x='bit_slice.51189', y='literal.51367')]
# FunctionName:  __sha256__main
# Input Expr:  add('add.37953',add('concat.30205','xor.18716'))
# [add(x='add.37953', y=add(x='concat.30205', y='xor.18716'))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('bit_slice.16224','concat.27384'),add('bit_slice.16233','concat.27401'))
# [add(x=add(x='bit_slice.16224', y='concat.27384'), y=add(x='bit_slice.16233', y='concat.27401')), add(x='concat.27384', y=add(x='bit_slice.16224', y=add(x='bit_slice.16233', y='concat.27401')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('bit_slice.16223','concat.27322'),add('bit_slice.16232','concat.27339'))
# [add(x=add(x='bit_slice.16223', y='concat.27322'), y=add(x='bit_slice.16232', y='concat.27339')), add(x='concat.27322', y=add(x='bit_slice.16223', y=add(x='bit_slice.16232', y='concat.27339')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('concat.30167','xor.18704'),'concat.51188')
# [add(x=add(x='concat.30167', y='xor.18704'), y='concat.51188'), add(x='xor.18704', y=add(x='concat.30167', y='concat.51188'))]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51229','literal.51375')
# [add(x='bit_slice.51229', y='literal.51375')]
# FunctionName:  __sha256__main
# Input Expr:  add(add('bit_slice.16222','concat.27260'),add('bit_slice.16231','concat.27277'))
# [add(x=add(x='bit_slice.16222', y='concat.27260'), y=add(x='bit_slice.16231', y='concat.27277')), add(x='concat.27260', y=add(x='bit_slice.16222', y=add(x='bit_slice.16231', y='concat.27277')))]
# FunctionName:  __sha256__main
# Input Expr:  add(add('bit_slice.16221','concat.27198'),add('bit_slice.16230','concat.27215'))
# [add(x=add(x='bit_slice.16221', y='concat.27198'), y=add(x='bit_slice.16230', y='concat.27215')), add(x='concat.27198', y=add(x='bit_slice.16221', y=add(x='bit_slice.16230', y='concat.27215')))]
# FunctionName:  __sha256__main
# Input Expr:  not_('add.51181')
# [not_(x='add.51181')]
# FunctionName:  __sha256__main
# Input Expr:  add('concat.51178','literal.23206')
# [add(x='concat.51178', y='literal.23206')]
# FunctionName:  __sha256__main
# Input Expr:  add('concat.51540','literal.51365')
# [add(x='concat.51540', y='literal.51365')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51557','literal.51374')
# [add(x='bit_slice.51557', y='literal.51374')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51555','literal.51373')
# [add(x='bit_slice.51555', y='literal.51373')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51553','literal.51372')
# [add(x='bit_slice.51553', y='literal.51372')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51551','literal.51371')
# [add(x='bit_slice.51551', y='literal.51371')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51549','literal.51370')
# [add(x='bit_slice.51549', y='literal.51370')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51547','literal.51369')
# [add(x='bit_slice.51547', y='literal.51369')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51545','literal.51368')
# [add(x='bit_slice.51545', y='literal.51368')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51543','literal.51366')
# [add(x='bit_slice.51543', y='literal.51366')]
# FunctionName:  __sha256__main
# Input Expr:  not_('bit_slice.51564')
# [not_(x='bit_slice.51564')]
# FunctionName:  __sha256__main
# Input Expr:  add('bit_slice.51537','literal.51364')
# [add(x='bit_slice.51537', y='literal.51364')]
# Scheduling Run Done.
# Reading Scheduling Result
# Result Graph Generation Done
# Max Pipeline Latency:  981
# Scheduling Run Done.
# Reading Scheduling Result
# Result Graph Generation Done
# Max Pipeline Latency:  981

# %%
# List of allowed operations
mapping_operations = ["add", "umul", "smul", "literal", "shll", "shrl", "not", 
                      "neg", "sub", "udiv", "sdiv", "bit_slice", "concat", "xor", "and", 
                      "nor", "tuple",None]

# Create a mapping for one-hot encoding
op_mapping = {op: i for i, op in enumerate(mapping_operations)}
num_ops = len(mapping_operations)

# Create a mapping of nodes to integers
node_mapping = {node: i for i, node in enumerate(G.nodes())}
num_nodes = len(node_mapping)

# Convert edges using the mapping
edges = torch.tensor([[node_mapping[u], node_mapping[v]] for u, v in G.edges()], dtype=torch.long).t().contiguous()

# Convert node attributes and include 'node_delay_ps', 'path_delay_ps', and one-hot encoded 'OperationType'
x = []
for node in G.nodes():
    node_features = [
        G.nodes[node]['node_delay_ps'],
        G.nodes[node]['path_delay_ps']
    ]
    op_type = G.nodes[node].get('OperationType')
    op_vector = [0] * num_ops  # Initialize with zeros
    if op_type is not None:
        op_vector[op_mapping[op_type]] = 1  # Set the corresponding index to 1 for one-hot encoding
    node_features.extend(op_vector)
    x.append(node_features)

x = torch.tensor(x, dtype=torch.float)

# Create PyTorch Geometric data
data = Data(x=x, edge_index=edges)

# Define the GNN Model
class GNN(torch.nn.Module):
    def __init__(self, n):
        super(GNN, self).__init__()
        # Adjust the input size to accommodate the operation type features
        self.conv1 = GCNConv(data.num_node_features, 16)
        self.conv2 = GCNConv(16, 32)
        self.linear = torch.nn.Linear(32, n)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = torch.nn.functional.relu(x)
        x = self.conv2(x, edge_index)
        x = self.linear(x)
        return x

# Instantiate the model (define 'n' as needed)
n = 10  # Example value for 'n'
model = GNN(n)

# Example forward pass
out = model(data)
print(out)  # Should be (num_nodes, n)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 21
#      18 x = []
#      19 for node in G.nodes():
#      20     node_features = [
# ---> 21         G.nodes[node]['node_delay_ps'],
#      22         G.nodes[node]['path_delay_ps']
#      23     ]
#      24     op_type = G.nodes[node].get('OperationType')
#      25     op_vector = [0] * num_ops  # Initialize with zeros
#
# KeyError: 'node_delay_ps'
